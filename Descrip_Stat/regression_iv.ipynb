# %%
import wrds
import time
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from datetime import datetime
from linearmodels.iv import IV2SLS
from linearmodels.iv import IVGMM

# %% [markdown]
# ### 1. Load Data

# %%
df_regression = pd.read_csv("df_main_reg.csv")

# %%
df_rank = pd.read_csv("../Ressell_Rank/RR_data/df_rank_switch.csv") 
# '../' means move up one directory

# %% [markdown]
# #### -1) Create quarterly panel for each cusip

# %%
# Extract year from date
df_rank['year'] = pd.to_datetime(df_rank['date']).dt.year

# define switch indicator
switch_indicators = df_rank[['cusip', 'year', 
                             'switch_to_r2000', 
                             'switch_to_r1000', 
                             'switch_to_r3000']]

# %% [markdown]
# #### -2) Merge the switch instrument to each quarter

# %%
# Create a 'year' column from your quarterly date
df_regression['year'] = pd.to_datetime(df_regression['date']).dt.year

df_regression = df_regression.merge(switch_indicators, on=['cusip', 'year'], how='left')
for col in ['switch_to_r2000', 'switch_to_r1000', 'switch_to_r3000']:
    df_regression[col] = df_regression[col].fillna(0).astype(int)

# %%
df_regression.head(3)
# Out:
#       cusip        date       bas         tno      mktcap  price_ind  \
# 0  00030710  2014-12-31  0.084839  332.131683  178.587706   0.039206
# 1  00030710  2015-03-31  0.051639  443.806176  274.286735   0.034110
# 2  00030710  2015-06-30  0.046190  581.424544  465.762113   0.027190
#
#       volume     illiq  volatility  synch  ...   act_own   ins_own  auto_lag1  \
# 0   7.001668  1.135563    0.277043 -3.648  ...  0.084358  0.234046      0.041
# 1   9.355878  1.095236    0.317542 -1.841  ...  0.131629  0.329042      0.223
# 2  12.664008  0.313499    0.249738 -2.326  ...  0.114851  0.349641      0.106
#
#    auto_lag2  auto_lag3  auto_lag4  year  switch_to_r2000  switch_to_r1000  \
# 0      0.169      0.203      0.078  2014                0                0
# 1      0.120      0.025      0.305  2015                0                0
# 2      0.062      0.202      0.156  2015                0                0
#
#    switch_to_r3000
# 0                0
# 1                0
# 2                0
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 2. OLS Regression with IV

# %%
# Define independent variables
market_quality_vars = ['bas', 'tno', 'illiq', 'volatility', 'synch', 'auto_lag1', 'auto_lag2', 'auto_lag3', 'auto_lag4']
Y = df_regression[market_quality_vars]

# %%
# Define X vars
index_var = ['ind_own']
control_vars = ['mktcap', 'price_ind', 'volume']

X_endog = df_regression[index_var]
X_exog = sm.add_constant(df_regression[control_vars]) #control vars are exogenous and add constant

# %%
# Define Instruments
instr_vars = ['switch_to_r2000', 'switch_to_r1000', 'switch_to_r3000']
Z_instr = df_regression[instr_vars]

# %% [markdown]
# #### Testing 2SLS Regression

# %%
# Example data (replace with your actual data)
data = pd.DataFrame({'y': [1, 2, 3, 4, 5], 'endog': [2, 3, 4, 5, 6], 'exog': [1, 2, 1, 2, 1], 'instruments': [3, 4, 5, 6, 7]})

# Define the model
formula = 'y ~ exog + [endog ~ instruments]'
mod = IV2SLS.from_formula(formula, data)
res = mod.fit()

# Access first-stage results
first_stage_results = res.first_stage
print(first_stage_results.diagnostics)
# Out:
#        rsquared  partial.rsquared  shea.rsquared       f.stat  f.pval   f.dist
# endog  0.997436          0.987677       0.987677  2477.854767     0.0  chi2(1)

# %% [markdown]
# #### IV Results

# %%
# Collect results
iv_results = {}

for yvar in Y.columns:
    y = df_regression[yvar]

    model = IV2SLS(
        dependent=y,
        exog=X_exog,
        endog=X_endog,
        instruments=Z_instr
    ).fit(cov_type='robust')

    iv_results[yvar] = model

# %%
# Collect summary statistics in a table
summary_table = pd.DataFrame({
    var: {
        'coef_ind_own': model.params.get('ind_own', float('nan')),
        'pval_ind_own': model.pvalues.get('ind_own', float('nan')),
        'r2': model.rsquared,
        'first_stage_F': model.first_stage.diagnostics.get('f.stat', float('nan')).iloc[0]
    }
    for var, model in iv_results.items()
}).T


print(summary_table)
# Out:
#             coef_ind_own  pval_ind_own        r2  first_stage_F
# bas             1.674338  0.000000e+00 -0.068685     647.760303
# tno        -14141.565259  0.000000e+00 -0.342196     647.760303
# illiq        -346.394626  5.847420e-01  0.019116     647.760303
# volatility     -0.309622  8.817234e-03  0.157438     647.760303
# synch          -3.783845  1.681509e-04 -0.047527     647.760303
# auto_lag1       0.661470  5.329071e-15 -0.169085     647.760303
# auto_lag2       0.231307  1.739217e-03 -0.024680     647.760303
# auto_lag3       0.079578  2.578633e-01 -0.003048     647.760303
# auto_lag4       0.040247  5.774556e-01 -0.001174     647.760303

# %%
model.first_stage.diagnostics
# Out:
#          rsquared  partial.rsquared  shea.rsquared      f.stat  f.pval  \
# ind_own  0.028917          0.001656       0.001656  647.760303     0.0
#
#           f.dist
# ind_own  chi2(3)

# %%
### 2. GMM(Generalized Method of Moments) Regression

# %%
gmm_results = {}

for yvar in Y.columns:
    y = df_regression[yvar]
    
    model = IVGMM(
        dependent=y,
        exog=X_exog,
        endog=X_endog,
        instruments=Z_instr
    )
    results = model.fit(cov_type='robust')
    gmm_results[yvar] = results
    
    print(f"Results for {yvar}")
    print(results.summary)
# Out:
# Results for bas
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                    bas   R-squared:                     -0.0695
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0695
# No. Observations:              258075   F-statistic:                    1397.9
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0000
# Time:                        03:28:51   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.0235     0.0122    -1.9280     0.0539     -0.0474      0.0004
# mktcap      1.812e-07  6.227e-08     2.9097     0.0036   5.913e-08   3.032e-07
# price_ind     -0.0137     0.0057    -2.3853     0.0171     -0.0250     -0.0024
# volume     -8.812e-05  6.448e-06    -13.666     0.0000     -0.0001  -7.548e-05
# ind_own        1.6855     0.1833     9.1970     0.0000      1.3263      2.0447
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for tno
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                    tno   R-squared:                     -0.3583
# Estimator:                     IV-GMM   Adj. R-squared:                -0.3583
# No. Observations:              258075   F-statistic:                    599.54
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0000
# Time:                        03:28:52   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          1521.0     75.412     20.170     0.0000      1373.2      1668.8
# mktcap         0.0005     0.0007     0.6819     0.4953     -0.0009      0.0018
# price_ind     -287.85     42.619    -6.7539     0.0000     -371.38     -204.31
# volume         0.9302     0.0786     11.838     0.0000      0.7762      1.0842
# ind_own    -1.433e+04     1064.4    -13.461     0.0000  -1.641e+04  -1.224e+04
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for illiq
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                  illiq   R-squared:                      0.0073
# Estimator:                     IV-GMM   Adj. R-squared:                 0.0073
# No. Observations:              258075   F-statistic:                    102.83
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0000
# Time:                        03:28:52   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          60.704     18.669     3.2516     0.0011      24.113      97.295
# mktcap         0.0008     0.0002     4.7458     0.0000      0.0004      0.0011
# price_ind      618.15     90.028     6.8662     0.0000      441.70      794.60
# volume        -0.0287     0.0063    -4.5260     0.0000     -0.0411     -0.0163
# ind_own       -1507.5     389.86    -3.8667     0.0001     -2271.6     -743.38
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for volatility
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:             volatility   R-squared:                      0.1545
# Estimator:                     IV-GMM   Adj. R-squared:                 0.1545
# No. Observations:              258075   F-statistic:                    1143.4
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0000
# Time:                        03:28:53   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1928     0.0078     24.643     0.0000      0.1775      0.2082
# mktcap     -5.112e-07  7.943e-08    -6.4353     0.0000  -6.668e-07  -3.555e-07
# price_ind      0.2524     0.0085     29.612     0.0000      0.2357      0.2691
# volume      4.994e-05  3.737e-06     13.366     0.0000   4.262e-05   5.727e-05
# ind_own        0.0359     0.1164     0.3085     0.7577     -0.1922      0.2640
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for synch
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                  synch   R-squared:                     -0.0244
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0245
# No. Observations:              258075   F-statistic:                    977.59
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0000
# Time:                        03:28:53   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -0.6993     0.0677    -10.330     0.0000     -0.8320     -0.5667
# mktcap      2.862e-06  5.114e-07     5.5959     0.0000   1.859e-06   3.864e-06
# price_ind     -1.1418     0.0514    -22.225     0.0000     -1.2425     -1.0411
# volume         0.0003  2.577e-05     12.680     0.0000      0.0003      0.0004
# ind_own       -3.0592     0.9937    -3.0787     0.0021     -5.0067     -1.1116
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag1
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag1   R-squared:                     -0.1800
# Estimator:                     IV-GMM   Adj. R-squared:                -0.1800
# No. Observations:              258075   F-statistic:                    278.99
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0000
# Time:                        03:28:54   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0754     0.0058     13.035     0.0000      0.0640      0.0867
# mktcap      -1.25e-07  2.571e-08    -4.8611     0.0000  -1.754e-07  -7.459e-08
# price_ind      0.0383     0.0032     11.889     0.0000      0.0320      0.0446
# volume     -1.826e-05  1.633e-06    -11.182     0.0000  -2.147e-05  -1.506e-05
# ind_own        0.6845     0.0843     8.1171     0.0000      0.5192      0.8498
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag2
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag2   R-squared:                     -0.0243
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0243
# No. Observations:              258075   F-statistic:                    21.234
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0003
# Time:                        03:28:55   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0922     0.0051     18.192     0.0000      0.0822      0.1021
# mktcap     -4.508e-08  1.295e-08    -3.4813     0.0005  -7.046e-08   -1.97e-08
# price_ind      0.0083     0.0026     3.2038     0.0014      0.0032      0.0134
# volume     -2.991e-06  9.107e-07    -3.2847     0.0010  -4.776e-06  -1.206e-06
# ind_own        0.2292     0.0738     3.1047     0.0019      0.0845      0.3739
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag3
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag3   R-squared:                     -0.0033
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0033
# No. Observations:              258075   F-statistic:                    10.797
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.0289
# Time:                        03:28:55   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.0989     0.0048     20.501     0.0000      0.0894      0.1083
# mktcap     -7.795e-09  1.355e-08    -0.5754     0.5650  -3.435e-08   1.876e-08
# price_ind      0.0049     0.0024     2.0015     0.0453      0.0001      0.0097
# volume     -1.265e-06  8.253e-07    -1.5328     0.1253  -2.883e-06   3.525e-07
# ind_own        0.0828     0.0703     1.1778     0.2389     -0.0550      0.2205
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag4
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag4   R-squared:                     -0.0013
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0013
# No. Observations:              258075   F-statistic:                    4.4670
# Date:                Wed, Jun 11 2025   P-value (F-stat)                0.3465
# Time:                        03:28:56   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1022     0.0050     20.604     0.0000      0.0925      0.1119
# mktcap     -1.473e-08  1.278e-08    -1.1528     0.2490  -3.977e-08   1.031e-08
# price_ind      0.0021     0.0025     0.8564     0.3918     -0.0028      0.0070
# volume     -7.448e-07  8.286e-07    -0.8989     0.3687  -2.369e-06   8.792e-07
# ind_own        0.0425     0.0722     0.5884     0.5563     -0.0991      0.1841
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: switch_to_r2000, switch_to_r1000, switch_to_r3000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)

# %%
summary_data = []

for yvar, model in gmm_results.items():
    summary_data.append({
        'yvar': yvar,
        'coef_ind_own': model.params.get('ind_own', float('nan')),
        'pval_ind_own': model.pvalues.get('ind_own', float('nan')),
        'r2': model.rsquared,
        'J-stat': model.j_stat.stat,
        'J-pval': model.j_stat.pval
    })

summary_table = pd.DataFrame(summary_data).set_index('yvar')
print(summary_table)
# Out:
#             coef_ind_own  pval_ind_own        r2      J-stat        J-pval
# yvar
# bas             1.685538  0.000000e+00 -0.069468   45.625561  1.237472e-10
# tno        -14327.242729  0.000000e+00 -0.358318   59.889704  9.892087e-14
# illiq       -1507.502328  1.103029e-04  0.007286   50.889674  8.901213e-12
# volatility      0.035907  7.576925e-01  0.154504  526.164688  0.000000e+00
# synch          -3.059171  2.078996e-03 -0.024444   92.677804  0.000000e+00
# auto_lag1       0.684537  4.440892e-16 -0.179953    7.601830  2.235031e-02
# auto_lag2       0.229184  1.905037e-03 -0.024250    0.933321  6.270929e-01
# auto_lag3       0.082761  2.388654e-01 -0.003288    3.024242  2.204420e-01
# auto_lag4       0.042498  5.562597e-01 -0.001283    1.899917  3.867571e-01
