# %%
import wrds
import time
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from datetime import datetime
from linearmodels.iv import IV2SLS
from linearmodels.iv import IVGMM

# %% [markdown]
# ### 1. Load Data and Merge IV Data

# %%
df_regression = pd.read_csv("df_main_reg.csv")
df_rank_iv = pd.read_csv("../Ressell_Rank/RR_data/df_rank_iv.csv") 
# '../' means move up one directory

# %% [markdown]
# #### -1) Merge the instrument to each quarter
# - the logic of the Russell 2000 instrument applies from Q3 of the reconstitution year through Q2 of the following year.
# - e.g. 2020.5.31 affects: 2020Q3, 2020Q4, 2021Q1, 2021Q2

# %%
# df_rank_iv: 5.31 of each year; df_regression: March, June, Sep, Dec of each year

# Step 1: Convert dates to datetime
df_regression['date'] = pd.to_datetime(df_regression['date'])
df_rank_iv['date'] = pd.to_datetime(df_rank_iv['date'])

# %%
# Step 2: Create effective year and quarter range for the instrument
# Shift date in the iv data forward by one month (to July 1st)
df_rank_iv['effective_start'] = df_rank_iv['date'] + pd.DateOffset(days=30)
df_rank_iv['effective_end'] = df_rank_iv['effective_start'] + pd.DateOffset(months=12)

# %%
df_rank_iv.head(3)
# Out:
#    permno  permco     cusip       date  mrkcap_crsp  tot_mrkcap_crsp cusip_co  \
# 0   10002    7954  05978R10 1999-05-31   103.737672       103.737672   05978R
# 1   10002    7954  05978R10 2001-05-31    97.293070        97.293070   05978R
# 2   10002    7954  05978R10 2002-05-31   100.734335       100.734335   05978R
#
#      gvkey      prccm     cshom  ...  ajexm  cshoq  ajexq  \
# 0  19049.0  13.421875  7.731100  ...    1.0  7.729    1.0
# 1  19049.0  11.410000  8.559727  ...    1.0  8.527    1.0
# 2  19049.0  11.720045  8.368000  ...    1.0  8.367    1.0
#
#    tot_mktcap_COMP_ALL  tot_mktcap_r3   mkt_value    Rank  assigned_to_R2000  \
# 0           103.765858     103.765858  103.765858  4703.0                  1
# 1            97.666488      97.666488   97.666488  4452.0                  1
# 2            98.073340     100.734335  100.734335  4302.0                  1
#
#    effective_start  effective_end
# 0       1999-06-30     2000-06-30
# 1       2001-06-30     2002-06-30
# 2       2002-06-30     2003-06-30
#
# [3 rows x 22 columns]

# %% [markdown]
# ##### clean data before merge
# - remove redundant columns from df_rank_iv
# - kept only cusips of rank<=5000

# %%
# Keep only CUSIPs from df_rank_iv
valid_cusips = df_rank_iv['cusip'].unique()
df_regression_clean = df_regression[df_regression['cusip'].isin(valid_cusips)].copy()

# %%
# Remove redundant columns
df_rank_iv_clean = df_rank_iv[['cusip', 'effective_start', 'effective_end', 'assigned_to_R2000']].copy()

# %% [markdown]
# ##### Exapnd the iv data to quarter frequency for merge

# %%
# Vectorized expansion using cross join with quarterly dates
# Create quarterly dates covering the full range
min_date = df_rank_iv_clean['effective_start'].min()
max_date = df_rank_iv_clean['effective_end'].max()
quarter_ends = pd.date_range(start=min_date, end=max_date, freq='Q')  # Quarter ends: Mar 31, Jun 30, Sep 30, Dec 31
# Out:
# /tmp/ipykernel_7360/225424294.py:5: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarter_ends = pd.date_range(start=min_date, end=max_date, freq='Q')  # Quarter ends: Mar 31, Jun 30, Sep 30, Dec 31

# %%
#Create DataFrame of all quarters
quarter_df = pd.DataFrame({'date': quarter_ends})
quarter_df['key'] = 1

#Add a key to df_rank_iv_clean for cross join
df_rank_iv_clean['key'] = 1

#Cross join to assign each firm all quarters
expanded = df_rank_iv_clean.merge(quarter_df, on='key').drop('key', axis=1)

#Keep only quarters within [effective_start, effective_end]
expanded = expanded[
    (expanded['date'] >= expanded['effective_start']) &
    (expanded['date'] <= expanded['effective_end'])
].copy()

#Keep only the useful columns
df_iv_quarters = expanded[['cusip', 'date', 'assigned_to_R2000']]

# %%
df_iv_quarters.head(3)
# Out:
#       cusip       date  assigned_to_R2000
# 0  05978R10 1999-06-30                  1
# 1  05978R10 1999-09-30                  1
# 2  05978R10 1999-12-31                  1

# %% [markdown]
# ##### merge iv data to df_regression

# %%
# Perform left merge so df_regression keeps all rows
df_regression_iv = df_regression_clean.merge(df_iv_quarters, on=['cusip', 'date'], how='left')

# Fill missing assigned_to_R2000 with 0 (not assigned)
df_regression_iv['assigned_to_R2000'] = df_regression_iv['assigned_to_R2000'].fillna(0).astype(int)

# %%
df_regression_iv.head(3)
# Out:
#       cusip       date       bas         tno      mktcap  price_ind  \
# 0  00030710 2014-12-31  0.084839  332.131683  178.587706   0.039206
# 1  00030710 2015-03-31  0.051639  443.806176  274.286735   0.034110
# 2  00030710 2015-06-30  0.046190  581.424544  465.762113   0.027190
#
#       volume     illiq  volatility  synch   ind_own   act_own   ins_own  \
# 0   7.001668  1.135563    0.277043 -3.648  0.012341  0.084358  0.234046
# 1   9.355878  1.095236    0.317542 -1.841  0.012512  0.131629  0.329042
# 2  12.664008  0.313499    0.249738 -2.326  0.017502  0.114851  0.349641
#
#    auto_lag1  auto_lag2  auto_lag3  auto_lag4  assigned_to_R2000
# 0      0.041      0.169      0.203      0.078                  0
# 1      0.223      0.120      0.025      0.305                  0
# 2      0.106      0.062      0.202      0.156                  1

# %%
df_regression_iv.shape
# Out:
# (290302, 18)

# %%
file_path_1 = 'df_regression_iv.csv' 
df_regression_iv.to_csv(file_path_1, index=False)

# %% [markdown]
# ### 2. OLS Regression with IV

# %%
# Define independent variables
market_quality_vars = ['bas', 'tno', 'illiq', 'volatility', 'synch', 'auto_lag1', 'auto_lag2', 'auto_lag3', 'auto_lag4']
Y = df_regression_iv[market_quality_vars]

# %%
# Define X vars
index_var = ['ind_own']
control_vars = ['mktcap', 'price_ind', 'volume']

X_endog = df_regression_iv[index_var]
X_exog = sm.add_constant(df_regression_iv[control_vars]) #control vars are exogenous and add constant

# %%
# Define Instruments
instr_vars = ['assigned_to_R2000']
Z_instr = df_regression_iv[instr_vars]

# %% [markdown]
# #### Testing 2SLS Regression

# %%
# Example data (replace with your actual data)
data = pd.DataFrame({'y': [1, 2, 3, 4, 5], 'endog': [2, 3, 4, 5, 6], 'exog': [1, 2, 1, 2, 1], 'instruments': [3, 4, 5, 6, 7]})

# Define the model
formula = 'y ~ exog + [endog ~ instruments]'
mod = IV2SLS.from_formula(formula, data)
res = mod.fit()

# Access first-stage results
first_stage_results = res.first_stage
print(first_stage_results.diagnostics)
# Out:
#        rsquared  partial.rsquared  shea.rsquared       f.stat  f.pval   f.dist
# endog  0.997436          0.987677       0.987677  2477.854767     0.0  chi2(1)

# %% [markdown]
# #### IV Results

# %%
# Collect results
iv_results = {}

for yvar in Y.columns:
    y = df_regression_iv[yvar]

    model = IV2SLS(
        dependent=y,
        exog=X_exog,
        endog=X_endog,
        instruments=Z_instr
    ).fit(cov_type='robust')

    iv_results[yvar] = model

# %%
# Collect summary statistics in a table
summary_table = pd.DataFrame({
    var: {
        'coef_ind_own': model.params.get('ind_own', float('nan')),
        'pval_ind_own': model.pvalues.get('ind_own', float('nan')),
        'r2': model.rsquared,
        'first_stage_F': model.first_stage.diagnostics.get('f.stat', float('nan')).iloc[0]
    }
    for var, model in iv_results.items()
}).T


print(summary_table)
# Out:
#             coef_ind_own  pval_ind_own        r2  first_stage_F
# bas            -1.763263      0.000000 -0.017424    6127.655981
# tno          7597.325190      0.000000 -0.079721    6127.655981
# illiq       -1518.313973      0.000000 -0.026057    6127.655981
# volatility      0.837717      0.000000  0.034907    6127.655981
# synch          12.496932      0.000000 -0.096696    6127.655981
# auto_lag1      -0.178987      0.000000  0.001134    6127.655981
# auto_lag2      -0.174687      0.000000 -0.010134    6127.655981
# auto_lag3       0.002546      0.877229  0.000061    6127.655981
# auto_lag4       0.015122      0.361680 -0.000172    6127.655981

# %%
model.first_stage.diagnostics
# Out:
#          rsquared  partial.rsquared  shea.rsquared      f.stat  f.pval  \
# ind_own  0.028917          0.001656       0.001656  647.760303     0.0
#
#           f.dist
# ind_own  chi2(3)

# %%
### 2. GMM(Generalized Method of Moments) Regression

# %%
gmm_results = {}

for yvar in Y.columns:
    y = df_regression_iv[yvar]
    
    model = IVGMM(
        dependent=y,
        exog=X_exog,
        endog=X_endog,
        instruments=Z_instr
    )
    results = model.fit(cov_type='robust')
    gmm_results[yvar] = results
    
    print(f"Results for {yvar}")
    print(results.summary)
# Out:
# Results for bas
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                    bas   R-squared:                     -0.0174
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0174
# No. Observations:              290302   F-statistic:                    807.63
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:52   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.2133     0.0056     38.183     0.0000      0.2024      0.2243
# mktcap      6.313e-07  6.035e-08     10.461     0.0000    5.13e-07   7.496e-07
# price_ind     -0.1648     0.0098    -16.821     0.0000     -0.1841     -0.1456
# volume     -5.589e-05  4.022e-06    -13.896     0.0000  -6.377e-05    -4.8e-05
# ind_own       -1.7633     0.0768    -22.951     0.0000     -1.9138     -1.6127
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for tno
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                    tno   R-squared:                     -0.0797
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0797
# No. Observations:              290302   F-statistic:                    361.06
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:53   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -16.533     34.959    -0.4729     0.6363     -85.050      51.985
# mktcap        -0.0022     0.0006    -3.5224     0.0004     -0.0035     -0.0010
# price_ind      499.10     33.385     14.950     0.0000      433.66      564.53
# volume         0.8994     0.0706     12.730     0.0000      0.7609      1.0379
# ind_own        7597.3     428.64     17.724     0.0000      6757.2      8437.4
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for illiq
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                  illiq   R-squared:                     -0.0261
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0261
# No. Observations:              290302   F-statistic:                    132.53
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:53   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          110.64     10.115     10.938     0.0000      90.814      130.46
# mktcap         0.0003  4.009e-05     6.4836     0.0000      0.0002      0.0003
# price_ind      56.676     13.981     4.0537     0.0001      29.273      84.078
# volume        -0.0064     0.0013    -5.0140     0.0000     -0.0089     -0.0039
# ind_own       -1518.3     141.98    -10.694     0.0000     -1796.6     -1240.0
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for volatility
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:             volatility   R-squared:                      0.0349
# Estimator:                     IV-GMM   Adj. R-squared:                 0.0349
# No. Observations:              290302   F-statistic:                    896.12
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:54   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1246     0.0040     30.978     0.0000      0.1168      0.1325
# mktcap     -4.254e-07  5.715e-08    -7.4430     0.0000  -5.374e-07  -3.134e-07
# price_ind      0.3456     0.0149     23.194     0.0000      0.3164      0.3748
# volume      4.141e-05  2.966e-06     13.961     0.0000    3.56e-05   4.723e-05
# ind_own        0.8377     0.0457     18.321     0.0000      0.7481      0.9273
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for synch
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:                  synch   R-squared:                     -0.0967
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0967
# No. Observations:              290302   F-statistic:                    5653.4
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:54   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -1.7069     0.0198    -86.356     0.0000     -1.7456     -1.6681
# mktcap      5.785e-07  1.682e-07     3.4402     0.0006   2.489e-07   9.082e-07
# price_ind     -0.6241     0.0344    -18.144     0.0000     -0.6915     -0.5567
# volume         0.0002  1.023e-05     14.693     0.0000      0.0001      0.0002
# ind_own        12.497     0.2657     47.030     0.0000      11.976      13.018
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag1
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag1   R-squared:                      0.0011
# Estimator:                     IV-GMM   Adj. R-squared:                 0.0011
# No. Observations:              290302   F-statistic:                    626.60
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:55   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1321     0.0014     91.867     0.0000      0.1293      0.1349
# mktcap      1.114e-10  9.635e-09     0.0116     0.9908  -1.877e-08     1.9e-08
# price_ind      0.0118     0.0015     8.1194     0.0000      0.0090      0.0147
# volume     -9.943e-06  8.054e-07    -12.345     0.0000  -1.152e-05  -8.364e-06
# ind_own       -0.1790     0.0199    -8.9966     0.0000     -0.2180     -0.1400
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag2
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag2   R-squared:                     -0.0101
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0101
# No. Observations:              290302   F-statistic:                    133.00
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0000
# Time:                        04:12:56   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1196     0.0012     95.803     0.0000      0.1171      0.1220
# mktcap      9.079e-09  8.487e-09     1.0697     0.2847  -7.556e-09   2.571e-08
# price_ind     -0.0055     0.0013    -4.2969     0.0000     -0.0080     -0.0030
# volume     -8.774e-07  6.424e-07    -1.3659     0.1720  -2.136e-06   3.816e-07
# ind_own       -0.1747     0.0173    -10.098     0.0000     -0.2086     -0.1408
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag3
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag3   R-squared:                   6.133e-05
# Estimator:                     IV-GMM   Adj. R-squared:              4.755e-05
# No. Observations:              290302   F-statistic:                    15.954
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0031
# Time:                        04:12:56   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1038     0.0012     87.851     0.0000      0.1015      0.1062
# mktcap     -2.318e-10  8.617e-09    -0.0269     0.9785  -1.712e-08   1.666e-08
# price_ind      0.0036     0.0011     3.1462     0.0017      0.0013      0.0058
# volume     -4.505e-07  5.698e-07    -0.7907     0.4291  -1.567e-06   6.662e-07
# ind_own        0.0025     0.0165     0.1545     0.8772     -0.0298      0.0348
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)
# Results for auto_lag4
#                           IV-GMM Estimation Summary
# ==============================================================================
# Dep. Variable:              auto_lag4   R-squared:                     -0.0002
# Estimator:                     IV-GMM   Adj. R-squared:                -0.0002
# No. Observations:              290302   F-statistic:                    11.917
# Date:                Wed, Jun 18 2025   P-value (F-stat)                0.0180
# Time:                        04:12:57   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.1047     0.0012     88.054     0.0000      0.1024      0.1070
# mktcap     -1.524e-08  7.426e-09    -2.0518     0.0402  -2.979e-08  -6.821e-10
# price_ind      0.0017     0.0011     1.5285     0.1264     -0.0005      0.0040
# volume     -8.496e-07  5.582e-07    -1.5221     0.1280  -1.944e-06   2.444e-07
# ind_own        0.0151     0.0166     0.9122     0.3617     -0.0174      0.0476
# ==============================================================================
#
# Endogenous: ind_own
# Instruments: assigned_to_R2000
# GMM Covariance
# Debiased: False
# Robust (Heteroskedastic)

# %%
summary_data = []

for yvar, model in gmm_results.items():
    summary_data.append({
        'yvar': yvar,
        'coef_ind_own': model.params.get('ind_own', float('nan')),
        'pval_ind_own': model.pvalues.get('ind_own', float('nan')),
        'r2': model.rsquared,
        'J-stat': model.j_stat.stat,
        'J-pval': model.j_stat.pval
    })

summary_table = pd.DataFrame(summary_data).set_index('yvar')
print(summary_table)
# Out:
#             coef_ind_own  pval_ind_own        r2        J-stat  J-pval
# yvar
# bas            -1.763263      0.000000 -0.017424  1.535018e-21     NaN
# tno          7597.325190      0.000000 -0.079721  1.054682e-21     NaN
# illiq       -1518.313973      0.000000 -0.026057  8.916299e-23     NaN
# volatility      0.837717      0.000000  0.034907  1.487093e-21     NaN
# synch          12.496932      0.000000 -0.096696  7.099225e-23     NaN
# auto_lag1      -0.178987      0.000000  0.001134  2.870644e-21     NaN
# auto_lag2      -0.174687      0.000000 -0.010134  4.900727e-21     NaN
# auto_lag3       0.002546      0.877229  0.000061  9.371964e-21     NaN
# auto_lag4       0.015122      0.361680 -0.000172  8.144827e-21     NaN
