# %%
import pandas as pd
import numpy as np
import wrds
from tqdm import tqdm

# %%
# Establish connection to WRDS
db = wrds.Connection()
# Out:
# Enter your WRDS username [ec2-user]: ly229
# Enter your password: ········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?:  y
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %% [markdown]
# ## Desrciptive Stat On Funds Holding under S&P500 and Russuell 3000

# %% [markdown]
# #### check tables under certain library(e.g Thomson-Reuters, CRSP) in wrds to find the correct name of database used

# %%
# List available tables in Thomson Reuters dataset
tables = db.list_tables(library="tfn")
print(tables)
# Out:
# ['amend', 'avgreturns', 'company', 'form144', 'header', 'idfhist', 'idfnames', 'rule10b5', 's12', 's12names', 's12type1', 's12type2', 's12type3', 's12type4', 's12type5', 's12type6', 's12type7', 's12type8', 's34', 's34names', 's34type1', 's34type2', 's34type3', 's34type4', 's34type6', 'table1', 'table2']

# %% [markdown]
# ### TNF Funding Holding Data - master file

# %%
# Query to retrieve mutual fund holdings data
query_tnf = """
    SELECT 
    fundno, fundname, 
    ticker, cusip, stkname, rdate, 
    assets/100 AS assets, 
    shares/1000000 AS shares_held, 
    shrout1
    
    FROM tfn.s12
    
    WHERE rdate BETWEEN '2023-01-01' AND '2023-12-31'
    AND country = 'UNITED STATES'
"""
#counts in millions(assets, shares, shrout1)

# %%
#huge dataset so inlcudes progress checking while downloading

# Use a temporary query to count total rows for progress tracking
count_query = "SELECT COUNT(shrout1) FROM tfn.s12 WHERE rdate BETWEEN '2023-01-01' AND '2023-12-31' AND country = 'UNITED STATES'"

# Get the total number of rows for progress tracking
total_rows = db.raw_sql(count_query).iloc[0, 0]

# Define chunk size
chunk_size = 10000  # Number of records per chunk

# Initialize an empty DataFrame to store the results
tnf = pd.DataFrame()

# %%
with tqdm(total=total_rows, desc='Downloading data', unit='row') as pbar:
    print("Loop Start")
    for chunk in db.raw_sql(count_query, chunksize=chunk_size):
        print("H")
        tnf = pd.concat([tnf, chunk], ignore_index=True)  # Concatenate each chunk into the main DataFrame
        pbar.update(len(chunk))  # Update the progress bar with the number of rows in the chunk


print(f"Total records downloaded: {len(tnf)}")
# Out:
# Downloading data:   0%|          | 0/8549371 [00:00<?, ?row/s]
# Loop Start
# Downloading data:   0%|          | 0/8549371 [01:06<?, ?row/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 with tqdm(total=total_rows, desc='Downloading data', unit='row') as pbar:
#       2     print("Loop Start")
# ----> 3     for chunk in db.raw_sql(query_tnf, chunksize=chunk_size):
#       4         print("H")
#       5         tnf = pd.concat([tnf, chunk], ignore_index=True)  # Concatenate each chunk into the main DataFrame
#
# File ~/miniconda3/lib/python3.12/site-packages/wrds/sql.py:579, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter)
#     577 else:
#     578     full_df = pd.DataFrame()
# --> 579     for chunk in df:
#     580         full_df = pd.concat([full_df, chunk])
#     581     return full_df
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/sql.py:1754, in SQLDatabase._query_iterator(result, exit_stack, chunksize, columns, index_col, coerce_float, parse_dates, dtype, dtype_backend)
#    1752 with exit_stack:
#    1753     while True:
# -> 1754         data = result.fetchmany(chunksize)
#    1755         if not data:
#    1756             if not has_read_data:
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/result.py:1360, in Result.fetchmany(self, size)
#    1341 def fetchmany(self, size: Optional[int] = None) -> Sequence[Row[_TP]]:
#    1342     """Fetch many rows.
#    1343
#    1344     When all rows are exhausted, returns an empty sequence.
#    (...)
#    1357
#    1358     """
# -> 1360     return self._manyrow_getter(self, size)
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/result.py:716, in ResultInternal._manyrow_getter.<locals>.manyrows(self, num)
#     709     real_result = (
#     710         self._real_result
#     711         if self._real_result
#     712         else cast("Result[Any]", self)
#     713     )
#     714     num = real_result._yield_per
# --> 716 rows: List[_InterimRowType[Any]] = self._fetchmany_impl(num)
#     717 if make_row:
#     718     rows = [make_row(row) for row in rows]
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/cursor.py:2138, in CursorResult._fetchmany_impl(self, size)
#    2137 def _fetchmany_impl(self, size=None):
# -> 2138     return self.cursor_strategy.fetchmany(self, self.cursor, size)
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/cursor.py:1128, in CursorFetchStrategy.fetchmany(self, result, dbapi_cursor, size)
#    1126     return l
#    1127 except BaseException as e:
# -> 1128     self.handle_exception(result, dbapi_cursor, e)
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/cursor.py:1081, in CursorFetchStrategy.handle_exception(self, result, dbapi_cursor, err)
#    1075 def handle_exception(
#    1076     self,
#    1077     result: CursorResult[Any],
#    1078     dbapi_cursor: Optional[DBAPICursor],
#    1079     err: BaseException,
#    1080 ) -> NoReturn:
# -> 1081     result.connection._handle_dbapi_exception(
#    1082         err, None, None, dbapi_cursor, result.context
#    1083     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2358, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2356     else:
#    2357         assert exc_info[1] is not None
# -> 2358         raise exc_info[1].with_traceback(exc_info[2])
#    2359 finally:
#    2360     del self._reentrant_error
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/cursor.py:1122, in CursorFetchStrategy.fetchmany(self, result, dbapi_cursor, size)
#    1120     l = dbapi_cursor.fetchmany()
#    1121 else:
# -> 1122     l = dbapi_cursor.fetchmany(size)
#    1124 if not l:
#    1125     result._soft_close()
#
# KeyboardInterrupt:

# %%
# Execute the query and store the result in a DataFrame
tnf = db.raw_sql(query_tnf)

# Display the first few records
print(tnf.head())

# %%
dt_path_1 = 'DS_data/tnf.csv' 
tnf.to_csv(dt_path_1, index=False)

# %% [markdown]
# ### S&P500 and Russell 3000 list from CRSP

# %%
# Describe the table to see available columns
db.describe_table(library="crsp", table="msp500list")  # Replace with your table name
# Out:
# Approximately 2047 rows in crsp.msp500list.
#      name  nullable     type                                         comment
# 0  permno      True  INTEGER                           CRSP Permanent Number
# 1   start      True     DATE    Date when the stock included in S&P500 Index
# 2  ending      True     DATE  Date when the stock excluded from S&P500 Index

# %%
db.describe_table(library="crsp", table="msf")
# Out:
# Approximately 5037353 rows in crsp.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True           INTEGER
# 2     permco      True           INTEGER
# 3     issuno      True           INTEGER
# 4      hexcd      True          SMALLINT
# 5     hsiccd      True           INTEGER
# 6       date      True              DATE
# 7      bidlo      True    NUMERIC(11, 5)
# 8      askhi      True    NUMERIC(11, 5)
# 9        prc      True    NUMERIC(11, 5)
# 10       vol      True    NUMERIC(10, 0)
# 11       ret      True    NUMERIC(10, 6)
# 12       bid      True    NUMERIC(11, 5)
# 13       ask      True    NUMERIC(11, 5)
# 14    shrout      True  DOUBLE PRECISION
# 15    cfacpr      True  DOUBLE PRECISION
# 16   cfacshr      True  DOUBLE PRECISION
# 17    altprc      True    NUMERIC(11, 5)
# 18    spread      True    NUMERIC(10, 5)
# 19  altprcdt      True              DATE
# 20      retx      True    NUMERIC(10, 6)
#
#                                     comment
# 0                              CUSIP Header
# 1                                    PERMNO
# 2                                    PERMCO
# 3                       Nasdaq Issue Number
# 4                      Exchange Code Header
# 5   Standard Industrial Classification Code
# 6                       Date of Observation
# 7                          Bid or Low Price
# 8                         Ask or High Price
# 9                  Price or Bid/Ask Average
# 10                                   Volume
# 11                                  Returns
# 12                                      Bid
# 13                                      Ask
# 14                       Shares Outstanding
# 15       Cumulative Factor to Adjust Prices
# 16   Cumulative Factor to Adjust Shares/Vol
# 17                          Price Alternate
# 18               Spread Between Bid and Ask
# 19                     Alternate Price Date
# 20                Returns without Dividends

# %%
sp500_list = db.raw_sql("""
                        SELECT a.*, 
                        b.date, b.cusip,
                        c.comnam, c.ticker
                        
                        FROM 
                        crsp.msp500list AS a

                        JOIN
                        crsp.msf AS b ON a.permno = b.permno
                        
                        JOIN
                        crsp.msenames AS c ON a.permno = c.permno
                        
                        WHERE 
                        b.date >= a.start 
                        AND b.date<= a.ending
                        AND b.date>='01/01/1993'
                        order by b.date;
                        """
                        )

# %%
sp500_list
# Out:
#         permno       start      ending        date     cusip  \
# 0        24643  1957-03-01  2023-12-29  1993-01-29  44320110
# 1        45356  1989-07-27  2009-03-16  1993-01-29  G5150210
# 2        70578  1989-01-12  2023-12-29  1993-01-29  27886510
# 3        21207  1969-05-15  2023-12-29  1993-01-29  65163910
# 4        18411  1944-06-07  2023-12-29  1993-01-29  84258710
# ...        ...         ...         ...         ...       ...
# 374145   82303  2017-06-19  2023-12-29  2023-12-29  G3223R10
# 374146   77129  2006-04-03  2023-12-29  2023-12-29  49446R10
# 374147   44601  1987-12-24  2023-12-29  2023-12-29  05361110
# 374148   60097  1986-10-23  2023-12-29  2023-12-29  G5960L10
# 374149   36468  1964-05-14  2023-12-29  2023-12-29  82434810
#
#                             comnam ticker
# 0                        ALCOA INC     AA
# 1       TYCO INTERNATIONAL LTD NEW    TYC
# 2                       ECOLAB INC    ECL
# 3            NEWMONT GOLDCORP CORP    NEM
# 4                      SOUTHERN CO     SO
# ...                            ...    ...
# 374145        EVEREST RE GROUP LTD     RE
# 374146           KIMCO REALTY CORP    KIM
# 374147         AVERY DENNISON CORP    AVY
# 374148               MEDTRONIC INC    MDT
# 374149         SHERWIN WILLIAMS CO    SHW
#
# [1374150 rows x 7 columns]

# %%
# Query to retrieve Russell 3000 companies from CRSP
russell3000_query = """
    SELECT permno, start, ending
    FROM crsp.mrussell3000
"""
russell3000_list = db.raw_sql(russell3000_query)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "crsp.mrussell3000" does not exist
# LINE 3:     FROM crsp.mrussell3000
#                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[12], line 6
#       1 # Query to retrieve Russell 3000 companies from CRSP
#       2 russell3000_query = """
#       3     SELECT permno, start, ending
#       4     FROM crsp.mrussell3000
#       5 """
# ----> 6 russell3000_list = db.raw_sql(russell3000_query)
#
# File ~/miniconda3/lib/python3.12/site-packages/wrds/sql.py:583, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter)
#     581         return full_df
#     582 except sa.exc.ProgrammingError as e:
# --> 583     raise e
#
# File ~/miniconda3/lib/python3.12/site-packages/wrds/sql.py:566, in Connection.raw_sql(self, sql, coerce_float, date_cols, index_col, params, chunksize, return_iter)
#     509 """
#     510 Queries the database using a raw SQL string.
#     511
#    (...)
#     562     2003-09-10  09:35:20.709000  N       AA       None     None  108100.0  28.200          N      00  1.929947e+15         C  None
#     563 """  # noqa
#     565 try:
# --> 566     df = pd.read_sql_query(
#     567         sql,
#     568         self.connection,
#     569         coerce_float=coerce_float,
#     570         parse_dates=date_cols,
#     571         index_col=index_col,
#     572         chunksize=chunksize,
#     573         params=params,
#     574     )
#     575     if return_iter or chunksize is None:
#     576         return df
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/io/sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "crsp.mrussell3000" does not exist
# LINE 3:     FROM crsp.mrussell3000
#                  ^
#
# [SQL:
#     SELECT permno, start, ending
#     FROM crsp.mrussell3000
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
