# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import wrds
from datetime import datetime
import time
import matplotlib.pyplot as plt

# %%
###################
# Connect to WRDS #
###################
conn=wrds.Connection()

# %% [markdown]
# ### 1. Load Data for Regression

# %%
df_regression = pd.read_csv("df_main_reg.csv")

# %%
lag_cols = ['auto_lag1', 'auto_lag2', 'auto_lag3', 'auto_lag4']
df_regression[lag_cols] = df_regression[lag_cols].abs()

# %%
file_path_1 = 'df_main_reg.csv' 
df_regression.to_csv(file_path_1, index=False)

# %%
df_regression.head(3)
# Out:
#       cusip        date       bas         tno      mktcap  price_ind  \
# 0  00030710  2014-12-31  0.084839  332.131683  178.587706   0.039206
# 1  00030710  2015-03-31  0.051639  443.806176  274.286735   0.034110
# 2  00030710  2015-06-30  0.046190  581.424544  465.762113   0.027190
#
#       volume     illiq  volatility  synch   ind_own   act_own   ins_own  \
# 0   7.001668  1.135563    0.277043 -3.648  0.012341  0.084358  0.234046
# 1   9.355878  1.095236    0.317542 -1.841  0.012512  0.131629  0.329042
# 2  12.664008  0.313499    0.249738 -2.326  0.017502  0.114851  0.349641
#
#    auto_lag1  auto_lag2  auto_lag3  auto_lag4
# 0      0.041      0.169      0.203      0.078
# 1      0.223      0.120      0.025      0.305
# 2      0.106      0.062      0.202      0.156

# %% [markdown]
# ### 2. Simple OLS Regression

# %% [markdown]
# #### -1) Dependet Var(Y) - Market Quality

# %%
# Define independent variables
market_quality_vars = ['bas', 'tno', 'illiq', 'volatility', 'synch', 'auto_lag1', 'auto_lag2', 'auto_lag3', 'auto_lag4']

# %%
# Dependent variable
Y = df_regression[market_quality_vars]

# %% [markdown]
# #### -2) Independet Var(X) - Index and Control Var

# %%
index_var = ['ind_own']
control_vars = ['mktcap', 'price_ind', 'volume']

# %%
X = df_regression[index_var + control_vars]
X = sm.add_constant(X)  # Add intercept

# %% [markdown]
# #### -3) OLS regreesion

# %%
Y_1 = df_regression[['bas', 'tno']]

# %%
import statsmodels.api as sm

results = {}
for col in Y.columns:  # Y is a DataFrame with multiple response variables
    model = sm.OLS(Y[col], X, missing='drop').fit()
    results[col] = model
    print(f"Results for {col}:")
    print(model.summary())
# Out:
# Results for bas:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    bas   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     515.0
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        03:14:17   Log-Likelihood:            -1.4533e+05
# No. Observations:              257312   AIC:                         2.907e+05
# Df Residuals:                  257307   BIC:                         2.907e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1301      0.001     90.607      0.000       0.127       0.133
# ind_own       -0.5427      0.016    -34.457      0.000      -0.574      -0.512
# mktcap      4.718e-07   4.67e-08     10.112      0.000     3.8e-07    5.63e-07
# price_ind     -0.0894      0.004    -24.462      0.000      -0.097      -0.082
# volume     -6.858e-05   3.45e-06    -19.877      0.000   -7.53e-05   -6.18e-05
# ==============================================================================
# Omnibus:                   742656.279   Durbin-Watson:                   0.183
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      58898582493.202
# Skew:                          39.582   Prob(JB):                         0.00
# Kurtosis:                    2345.503   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for tno:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tno   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     4473.
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        03:14:17   Log-Likelihood:            -2.1871e+06
# No. Observations:              257312   AIC:                         4.374e+06
# Df Residuals:                  257307   BIC:                         4.374e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        471.5155      4.012    117.517      0.000     463.651     479.380
# ind_own      560.8990     43.993     12.750      0.000     474.675     647.123
# mktcap        -0.0025      0.000    -18.941      0.000      -0.003      -0.002
# price_ind    214.2447     10.208     20.987      0.000     194.237     234.253
# volume         1.1898      0.010    123.448      0.000       1.171       1.209
# ==============================================================================
# Omnibus:                   820611.227   Durbin-Watson:                   1.162
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     484486218680.365
# Skew:                          51.370   Prob(JB):                         0.00
# Kurtosis:                    6724.490   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for illiq:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  illiq   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     1281.
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        03:14:17   Log-Likelihood:            -2.0838e+06
# No. Observations:              257312   AIC:                         4.168e+06
# Df Residuals:                  257307   BIC:                         4.168e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -16.8123      2.685     -6.261      0.000     -22.076     -11.549
# ind_own      -58.8599     29.443     -1.999      0.046    -116.568      -1.152
# mktcap         0.0004   8.72e-05      4.412      0.000       0.000       0.001
# price_ind    480.8909      6.832     70.386      0.000     467.500     494.282
# volume        -0.0433      0.006     -6.706      0.000      -0.056      -0.031
# ==============================================================================
# Omnibus:                  1059963.423   Durbin-Watson:                   0.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    2969174809281.425
# Skew:                         112.533   Prob(JB):                         0.00
# Kurtosis:                   16643.017   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for volatility:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             volatility   R-squared:                       0.159
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                 1.219e+04
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        03:14:17   Log-Likelihood:             1.3301e+05
# No. Observations:              257312   AIC:                        -2.660e+05
# Df Residuals:                  257307   BIC:                        -2.659e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2058      0.000    422.564      0.000       0.205       0.207
# ind_own       -0.1687      0.005    -31.596      0.000      -0.179      -0.158
# mktcap     -3.831e-07   1.58e-08    -24.218      0.000   -4.14e-07   -3.52e-07
# price_ind      0.2527      0.001    203.938      0.000       0.250       0.255
# volume      5.581e-05   1.17e-06     47.712      0.000    5.35e-05    5.81e-05
# ==============================================================================
# Omnibus:                   305746.886   Durbin-Watson:                   1.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        231535705.650
# Skew:                           5.649   Prob(JB):                         0.00
# Kurtosis:                     149.520   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for synch:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  synch   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     6484.
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):               0.00
# Time:                        03:14:17   Log-Likelihood:            -3.9792e+05
# No. Observations:              257312   AIC:                         7.959e+05
# Df Residuals:                  257307   BIC:                         7.959e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.2209      0.004   -318.498      0.000      -1.228      -1.213
# ind_own        4.5608      0.042    108.512      0.000       4.478       4.643
# mktcap      1.884e-06   1.25e-07     15.129      0.000    1.64e-06    2.13e-06
# price_ind     -0.8839      0.010    -90.632      0.000      -0.903      -0.865
# volume         0.0002   9.21e-06     26.667      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                    18343.448   Durbin-Watson:                   1.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35710.506
# Skew:                          -0.503   Prob(JB):                         0.00
# Kurtosis:                       4.522   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for auto_lag1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              auto_lag1   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     359.7
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):          2.04e-309
# Time:                        03:14:17   Log-Likelihood:             2.3868e+05
# No. Observations:              257312   AIC:                        -4.773e+05
# Df Residuals:                  257307   BIC:                        -4.773e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1286      0.000    398.335      0.000       0.128       0.129
# ind_own       -0.0913      0.004    -25.781      0.000      -0.098      -0.084
# mktcap     -1.358e-08   1.05e-08     -1.294      0.196   -3.41e-08    6.99e-09
# price_ind      0.0124      0.001     15.142      0.000       0.011       0.014
# volume      -1.23e-05   7.76e-07    -15.862      0.000   -1.38e-05   -1.08e-05
# ==============================================================================
# Omnibus:                    47183.105   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            86185.554
# Skew:                           1.160   Prob(JB):                         0.00
# Kurtosis:                       4.630   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for auto_lag2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              auto_lag2   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     7.078
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):           1.08e-05
# Time:                        03:14:17   Log-Likelihood:             2.7673e+05
# No. Observations:              257312   AIC:                        -5.534e+05
# Df Residuals:                  257307   BIC:                        -5.534e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1088      0.000    390.589      0.000       0.108       0.109
# ind_own       -0.0125      0.003     -4.093      0.000      -0.018      -0.007
# mktcap     -9.899e-09   9.05e-09     -1.094      0.274   -2.76e-08    7.84e-09
# price_ind      0.0001      0.001      0.173      0.862      -0.001       0.002
# volume     -1.314e-06   6.69e-07     -1.964      0.050   -2.63e-06   -2.71e-09
# ==============================================================================
# Omnibus:                    39660.170   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63689.589
# Skew:                           1.064   Prob(JB):                         0.00
# Kurtosis:                       4.188   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for auto_lag3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              auto_lag3   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.940
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):             0.0192
# Time:                        03:14:17   Log-Likelihood:             2.8456e+05
# No. Observations:              257312   AIC:                        -5.691e+05
# Df Residuals:                  257307   BIC:                        -5.691e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1048      0.000    387.985      0.000       0.104       0.105
# ind_own       -0.0037      0.003     -1.256      0.209      -0.010       0.002
# mktcap      4.597e-09   8.78e-09      0.524      0.600   -1.26e-08    2.18e-08
# price_ind      0.0020      0.001      2.858      0.004       0.001       0.003
# volume     -6.129e-07   6.49e-07     -0.944      0.345   -1.88e-06    6.59e-07
# ==============================================================================
# Omnibus:                    36566.109   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            55523.309
# Skew:                           1.031   Prob(JB):                         0.00
# Kurtosis:                       3.963   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Results for auto_lag4:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              auto_lag4   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     5.813
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):           0.000113
# Time:                        03:14:17   Log-Likelihood:             2.8557e+05
# No. Observations:              257312   AIC:                        -5.711e+05
# Df Residuals:                  257307   BIC:                        -5.711e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1060      0.000    393.737      0.000       0.105       0.106
# ind_own       -0.0129      0.003     -4.383      0.000      -0.019      -0.007
# mktcap     -7.379e-09   8.74e-09     -0.844      0.399   -2.45e-08    9.76e-09
# price_ind      0.0004      0.001      0.534      0.593      -0.001       0.002
# volume      -2.69e-07   6.46e-07     -0.416      0.677   -1.54e-06    9.98e-07
# ==============================================================================
# Omnibus:                    34825.211   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            51741.844
# Skew:                           1.003   Prob(JB):                         0.00
# Kurtosis:                       3.895   Cond. No.                     3.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
summary_rows = []

for dep_var, model in results.items():
    coef_df = model.summary2().tables[1]  # This table has coef, std err, t, p
    coef_df = coef_df.reset_index().rename(columns={'index': 'variable'})
    coef_df['dependent_var'] = dep_var
    coef_df['r_squared'] = model.rsquared
    summary_rows.append(coef_df)

# Combine all into one DataFrame
summary_table = pd.concat(summary_rows, ignore_index=True)

# Optional: reorder columns for readability
summary_table = summary_table[['dependent_var', 'variable', 'Coef.', 'Std.Err.', 't', 'P>|t|', 'r_squared']]

print(summary_table)
# Out:
#    dependent_var   variable         Coef.      Std.Err.           t  \
# 0            bas      const  1.301436e-01  1.436349e-03   90.607199
# 1            bas    ind_own -5.426557e-01  1.574864e-02  -34.457310
# 2            bas     mktcap  4.718136e-07  4.665944e-08   10.111858
# 3            bas  price_ind -8.939195e-02  3.654392e-03  -24.461510
# 4            bas     volume -6.858059e-05  3.450217e-06  -19.877179
# 5            tno      const  4.715155e+02  4.012331e+00  117.516590
# 6            tno    ind_own  5.608990e+02  4.399261e+01   12.749845
# 7            tno     mktcap -2.468761e-03  1.303396e-04  -18.940991
# 8            tno  price_ind  2.142447e+02  1.020826e+01   20.987373
# 9            tno     volume  1.189778e+00  9.637918e-03  123.447613
# 10         illiq      const -1.681233e+01  2.685367e+00   -6.260720
# 11         illiq    ind_own -5.885988e+01  2.944331e+01   -1.999092
# 12         illiq     mktcap  3.849141e-04  8.723348e-05    4.412458
# 13         illiq  price_ind  4.808909e+02  6.832172e+00   70.386243
# 14         illiq     volume -4.325467e-02  6.450452e-03   -6.705680
# 15    volatility      const  2.057634e-01  4.869396e-04  422.564463
# 16    volatility    ind_own -1.686899e-01  5.338977e-03  -31.595925
# 17    volatility     mktcap -3.830895e-07  1.581811e-08  -24.218412
# 18    volatility  price_ind  2.526554e-01  1.238883e-03  203.938135
# 19    volatility     volume  5.580648e-05  1.169665e-06   47.711506
# 20         synch      const -1.220928e+00  3.833393e-03 -318.498062
# 21         synch    ind_own  4.560846e+00  4.203067e-02  108.512326
# 22         synch     mktcap  1.884006e-06  1.245268e-07   15.129318
# 23         synch  price_ind -8.839327e-01  9.753006e-03  -90.631822
# 24         synch     volume  2.455567e-04  9.208096e-06   26.667473
# 25     auto_lag1      const  1.286382e-01  3.229396e-04  398.335218
# 26     auto_lag1    ind_own -9.128590e-02  3.540824e-03  -25.780980
# 27     auto_lag1     mktcap -1.357526e-08  1.049061e-08   -1.294039
# 28     auto_lag1  price_ind  1.244147e-02  8.216304e-04   15.142412
# 29     auto_lag1     volume -1.230480e-05  7.757250e-07  -15.862316
# 30     auto_lag2      const  1.087965e-01  2.785446e-04  390.589142
# 31     auto_lag2    ind_own -1.250082e-02  3.054061e-03   -4.093179
# 32     auto_lag2     mktcap -9.898596e-09  9.048452e-09   -1.093955
# 33     auto_lag2  price_ind  1.227808e-04  7.086795e-04    0.173253
# 34     auto_lag2     volume -1.314097e-06  6.690848e-07   -1.964022
# 35     auto_lag3      const  1.048312e-01  2.701939e-04  387.985157
# 36     auto_lag3    ind_own -3.720151e-03  2.962501e-03   -1.255747
# 37     auto_lag3     mktcap  4.597453e-09  8.777181e-09    0.523796
# 38     auto_lag3  price_ind  1.964624e-03  6.874335e-04    2.857911
# 39     auto_lag3     volume -6.128846e-07  6.490259e-07   -0.944315
# 40     auto_lag4      const  1.059674e-01  2.691326e-04  393.736726
# 41     auto_lag4    ind_own -1.293454e-02  2.950865e-03   -4.383305
# 42     auto_lag4     mktcap -7.379067e-09  8.742706e-09   -0.844025
# 43     auto_lag4  price_ind  3.656377e-04  6.847334e-04    0.533985
# 44     auto_lag4     volume -2.690062e-07  6.464766e-07   -0.416111
#
#             P>|t|  r_squared
# 0    0.000000e+00   0.007943
# 1   1.374171e-259   0.007943
# 2    4.945662e-24   0.007943
# 3   5.378580e-132   0.007943
# 4    7.469127e-88   0.007943
# 5    0.000000e+00   0.065020
# 6    3.205883e-37   0.065020
# 7    5.941643e-80   0.065020
# 8    1.033557e-97   0.065020
# 9    0.000000e+00   0.065020
# 10   3.838042e-10   0.019523
# 11   4.559946e-02   0.019523
# 12   1.022449e-05   0.019523
# 13   0.000000e+00   0.019523
# 14   2.008815e-11   0.019523
# 15   0.000000e+00   0.159295
# 16  1.105431e-218   0.159295
# 17  1.989753e-129   0.159295
# 18   0.000000e+00   0.159295
# 19   0.000000e+00   0.159295
# 20   0.000000e+00   0.091567
# 21   0.000000e+00   0.091567
# 22   1.092293e-51   0.091567
# 23   0.000000e+00   0.091567
# 24  1.835712e-156   0.091567
# 25   0.000000e+00   0.005560
# 26  2.227337e-146   0.005560
# 27   1.956532e-01   0.005560
# 28   8.952991e-52   0.005560
# 29   1.229381e-56   0.005560
# 30   0.000000e+00   0.000110
# 31   4.256289e-05   0.000110
# 32   2.739759e-01   0.000110
# 33   8.624527e-01   0.000110
# 34   4.952864e-02   0.000110
# 35   0.000000e+00   0.000046
# 36   2.092090e-01   0.000046
# 37   6.004208e-01   0.000046
# 38   4.264743e-03   0.000046
# 39   3.450098e-01   0.000046
# 40   0.000000e+00   0.000090
# 41   1.169384e-05   0.000090
# 42   3.986560e-01   0.000090
# 43   5.933520e-01   0.000090
# 44   6.773289e-01   0.000090
