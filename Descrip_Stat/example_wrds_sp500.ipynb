# %% [markdown]
# ## This code illustrates how to get S&P500 index constituents and their identifiers from CRSP and Compustat
# - Researchers used to be able to extract index membership information from Compustat's "comp.idxcst_his" data. Now that S&P pulled this piece of data off from WRDS platform, we have to turn to CRSP to get S&P500 Index membership data.
# - Unfortunately, there is no easy way to uncover constituents info for the other indices covered by "comp.idxcst_his".

# %%
##########################################
# S&P 500 Index Constituents             #
# Qingyi (Freda) Song Drechsler          #
# Date: October 2020                     #
##########################################

import pandas as pd
import wrds

# %%
import numpy as np

# %% [markdown]
# ### Step 1: Connect to WRDS

# %%
###################
# Connect to WRDS #
###################
conn=wrds.Connection()
# Out:
# Enter your WRDS username [ec2-user]: ly229
# Enter your password: ········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?:  y
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %% [markdown]
# ### Step 2: Get SP500 Index Membership from CRSP
# - I opt for the monthly frequency of the data, but one can choose to work with crsp.dsp500list if more precise date range is needed.

# %%
sp500 = conn.raw_sql("""
                        select 
                        a.*, b.date, b.ret
                        
                        from crsp.msp500list as a,
                        crsp.msf as b
                        
                        where a.permno=b.permno
                        and b.date >= a.start and b.date<= a.ending
                        and b.date>='01/01/2000'
                        order by date;
                        """, date_cols=['start', 'ending', 'date'])

# %%
sp500.head()
# Out:
#     permno      start     ending       date       ret
# 0  75175.0 1996-12-03 2009-12-18 2000-01-31 -0.052071
# 1  22840.0 1981-09-10 2012-06-28 2000-01-31 -0.164306
# 2  79973.0 1998-04-27 2006-07-31 2000-01-31 -0.150911
# 3  12431.0 1957-03-01 2009-06-30 2000-01-31 -0.145289
# 4  75789.0 1992-01-02 2008-09-10 2000-01-31  0.066401

# %% [markdown]
# ### Step 3: Add Other Company Identifiers from CRSP.MSENAMES
# - You don't need this step if only PERMNO is required
# - This step aims to add TICKER, SHRCD, EXCHCD and etc.

# %%
# Add Other Descriptive Variables

mse = conn.raw_sql("""
                        select comnam, ncusip, namedt, nameendt, 
                        permno, shrcd, exchcd, hsiccd, ticker
                        from crsp.msenames
                        """, date_cols=['namedt', 'nameendt'])

# if nameendt is missing then set to today date
mse['nameendt']=mse['nameendt'].fillna(pd.to_datetime('today'))

# %%
mse.sample(5)
# Out:
#                               comnam    ncusip     namedt   nameendt   permno  \
# 45668    PENN MEDICAL TECHNOLOGY INC  70754810 1984-04-03 1984-10-16  61939.0
# 100555                   SIMCLAR INC  82859910 2006-06-30 2008-04-24  92340.0
# 16891            CAMBRIA E T F TRUST  13206185 2017-05-24 2017-12-25  16740.0
# 64564   BUILDERS WAREHOUSE ASSOC INC  11991630 1995-05-10 1995-06-29  79154.0
# 31856         SHATTUCK DENN MNG CORP  82024210 1968-01-02 1973-05-22  36433.0
#
#         shrcd  exchcd  hsiccd ticker
# 45668    10.0     3.0  3843.0   PEMD
# 100555   11.0     3.0  3670.0   SIMC
# 16891    73.0     4.0  6726.0   CCOR
# 64564    11.0     3.0  5210.0   BWAI
# 31856    10.0     2.0  3499.0    SDE

# %%
# Merge with SP500 data
sp500_full = pd.merge(sp500, mse, how = 'left', on = 'permno')

# Impose the date range restrictions
sp500_full = sp500_full.loc[(sp500_full.date>=sp500_full.namedt) \
                            & (sp500_full.date<=sp500_full.nameendt)]
sp500_full.sample(5)
# Out:
#         permno      start     ending       date       ret  \
# 263452   13856 1957-03-01 2023-12-29 2005-10-31  0.041792
# 607800   70578 1989-01-12 2023-12-29 2013-04-30  0.055375
# 123533   83332 1996-10-01 2006-11-30 2002-09-30 -0.560694
# 811368   77605 1995-02-24 2023-12-29 2017-10-31 -0.035310
# 414416   76149 1998-11-13 2015-01-26 2009-01-30 -0.098443
#
#                          comnam    ncusip     namedt   nameendt  shrcd  \
# 263452              PEPSICO INC  71344810 2004-06-10 2017-12-19     11
# 607800               ECOLAB INC  27886510 2004-06-10 2017-03-09     11
# 123533  LUCENT TECHNOLOGIES INC  54946310 2002-01-02 2004-02-19     11
# 811368   BOSTON SCIENTIFIC CORP  10113710 2004-06-10 2023-12-29     11
# 414416              SAFEWAY INC  78651420 2004-06-10 2015-01-29     11
#
#         exchcd  hsiccd ticker
# 263452       1    2086    PEP
# 607800       1    2841    ECL
# 123533       1    3661     LU
# 811368       1    3841    BSX
# 414416       1    5411    SWY

# %% [markdown]
# ### Step 4: Add Compustat Identifiers
# - Link with Compustat's GVKEY and IID if need to work with fundamental data
# - Linkage is done through crsp.ccmxpf_linktable

# %%
# Linking with Compustat through CCM

ccm=conn.raw_sql("""
                  select gvkey, liid as iid, lpermno as permno, linktype, linkprim, 
                  linkdt, linkenddt
                  from crsp.ccmxpf_linktable
                  where substr(linktype,1,1)='L'
                  and (linkprim ='C' or linkprim='P')
                  """, date_cols=['linkdt', 'linkenddt'])

# if linkenddt is missing then set to today date
ccm['linkenddt']=ccm['linkenddt'].fillna(pd.to_datetime('today'))

# %%
# Merge the CCM data with S&P500 data
# First just link by matching PERMNO
sp500ccm = pd.merge(sp500_full, ccm, how='left', on=['permno'])

# Then set link date bounds
sp500ccm = sp500ccm.loc[(sp500ccm['date']>=sp500ccm['linkdt'])\
                        &(sp500ccm['date']<=sp500ccm['linkenddt'])]
sp500ccm.sample(5)
# Out:
#         permno      start     ending       date       ret  \
# 153045   92121 2007-07-02 2023-12-29 2019-12-31 -0.000589
# 103593   86725 2008-11-24 2014-01-23 2013-04-30  0.140183
# 32294    37584 1998-04-29 2023-12-29 2003-12-31  0.090215
# 116852   19502 1979-10-11 2023-12-29 2015-02-27  0.131085
# 80948    38703 1976-07-01 2023-12-29 2010-04-30  0.063946
#
#                               comnam    ncusip     namedt   nameendt  shrcd  \
# 153045   DISCOVER FINANCIAL SERVICES  25470910 2017-04-26 2020-02-17     11
# 103593        LIFE TECHNOLOGIES CORP  53217V10 2008-11-24 2014-02-03     11
# 32294         FRANKLIN RESOURCES INC  35461310 2002-01-02 2004-02-16     11
# 116852  WALGREENS BOOTS ALLIANCE INC  93142710 2014-12-31 2023-12-29     11
# 80948           WELLS FARGO & CO NEW  94974610 2004-06-10 2012-10-11     11
#
#         exchcd  hsiccd ticker   gvkey iid linktype linkprim     linkdt  \
# 153045       1    6022    DFS  177376  02       LC        P 2007-07-02
# 103593       3    2836   LIFE  118577  01       LC        P 1999-02-26
# 32294        1    6282    BEN  004885  01       LU        P 1983-09-23
# 116852       3    5912    WBA  011264  01       LU        P 1962-01-31
# 80948        1    6021    WFC  008007  01       LC        P 1962-12-10
#
#                         linkenddt
# 153045 2024-10-27 03:21:48.429932
# 103593 2014-02-03 00:00:00.000000
# 32294  2024-10-27 03:21:48.429932
# 116852 2024-10-27 03:21:48.429932
# 80948  2024-10-27 03:21:48.429932

# %%
# Rearrange columns for final output

sp500ccm = sp500ccm.drop(columns=['namedt', 'nameendt', \
                                  'linktype', 'linkprim', 'linkdt', 'linkenddt'])
sp500ccm = sp500ccm[['date', 'permno', 'comnam', 'ncusip', 'shrcd', 'exchcd', 'hsiccd', 'ticker', \
                     'gvkey', 'iid', 'start', 'ending', 'ret']]
sp500ccm.sample(5)
# Out:
#             date  permno                         comnam    ncusip  shrcd  \
# 80323 2010-03-31   85032  QWEST COMMUNICATIONS INTL INC  74912110     11
# 55833 2007-01-31   23660                    CINTAS CORP  17290810     11
# 82562 2010-07-30   23501             PEPCO HOLDINGS INC  71329110     11
# 4015  2000-06-30   48485           JEFFERSON PILOT CORP  47507010     11
# 39995 2004-12-31   76557                   M B N A CORP  55262L10     11
#
#        exchcd  hsiccd ticker   gvkey iid      start     ending       ret
# 80323       1    4813      Q  061489  01 2000-07-06 2011-03-31  0.144737
# 55833       3    2320   CTAS  003062  01 2001-03-01 2023-12-29  0.036263
# 82562       1    4931    POM  008694  01 2007-11-09 2016-03-29  0.078444
# 4015        1    6311     JP  006241  01 1976-07-01 2006-03-31 -0.177596
# 39995       1    6021    KRB  023592  01 1992-04-23 2005-12-30  0.065889

# %%
cnt = sp500ccm.groupby(['date'])['permno'].count().reset_index().rename(columns={'permno':'npermno'})
cnt.sample(4)
# Out:
#           date  npermno
# 251 2020-12-31      501
# 100 2008-05-30      500
# 197 2016-06-30      501
# 258 2021-07-30      500

# %%
sp500ccm.sample(10)
# Out:
#              date   permno                            comnam    ncusip  shrcd  \
# 113348 2014-11-28  26825.0                        KELLOGG CO  48783610   11.0
# 507    2000-01-31  80599.0      LEHMAN BROTHERS HOLDINGS INC  52490810   11.0
# 60387  2007-10-31  40272.0  INTERNATIONAL FLAVORS & FRAG INC  45950610   11.0
# 50310  2006-06-30  78034.0           PATTERSON COMPANIES INC  70339510   11.0
# 97932  2012-10-31  16600.0                        HERSHEY CO  42786610   11.0
# 70840  2009-02-27  24766.0             NORTHROP GRUMMAN CORP  66680710   11.0
# 23639  2002-12-31  13119.0                       MAYTAG CORP  57859210   11.0
# 112012 2014-09-30  28345.0                   MURPHY OIL CORP  62671710   11.0
# 93624  2012-03-30  52329.0      JACOBS ENGINEERING GROUP INC  46981410   11.0
# 114295 2015-01-30  91461.0                  WESTERN UNION CO  95980210   11.0
#
#         exchcd  hsiccd ticker   gvkey iid      start     ending       ret
# 113348     1.0  2043.0      K  006375  01 1961-04-26 2019-12-31  0.043465
# 507        1.0  6282.0    LEH  030128  01 1998-01-12 2008-09-16 -0.157934
# 60387      1.0  2869.0    IFF  006078  01 1976-03-04 2019-12-31 -0.012297
# 50310      3.0  5990.0   PDCO  025880  01 2005-10-11 2018-03-16  0.019854
# 97932      1.0  2066.0    HSY  005597  01 1957-03-01 2019-12-31 -0.028777
# 70840      1.0  3812.0    NOC  007985  01 1985-06-13 2019-12-31 -0.215295
# 23639      1.0  3633.0    MYG  007139  01 1960-12-14 2006-03-31 -0.079457
# 112012     1.0  1382.0    MUR  007620  01 2005-08-15 2017-07-25 -0.089003
# 93624      1.0  8711.0    JEC  006216  01 2007-10-26 2019-12-31 -0.040026
# 114295     1.0  6099.0     WU  175263  01 2006-10-02 2019-12-31 -0.050810

# %%
### create a link table of PERMNO, CUSIP, GVKEY, IID
sp500_dates = sp500ccm[['start', 'ending', 'permno', 'ncusip', 'ticker', 'gvkey']].copy()

# %%
# Convert start and end columns to datetime
sp500_dates['start'] = pd.to_datetime(sp500_dates['start'])
sp500_dates['ending'] = pd.to_datetime(sp500_dates['ending'])

# Function to generate quarterly dates between start and end
def generate_quarterly_dates(start, end):
    # Create a date range from start to end with quarterly frequency
    return pd.date_range(start=start, end=end, freq='QE').to_list()

# Apply the function to each row
sp500_dates['quarters'] = sp500_dates.apply(lambda row: generate_quarterly_dates(row['start'], row['ending']), axis=1)

# Expand the quarters column into individual rows
sp500_dates_q = sp500_dates.explode('quarters').reset_index(drop=True)
print(sp500_dates_q)
# Out:
# /tmp/ipykernel_3066/1129209110.py:8: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   return pd.date_range(start=start, end=end, freq='Q').to_list()
#               start     ending  permno    ncusip ticker   gvkey   quarters
# 0        1999-07-22 2023-12-29   77178  74752510   QCOM  024800 1999-09-30
# 1        1999-07-22 2023-12-29   77178  74752510   QCOM  024800 1999-12-31
# 2        1999-07-22 2023-12-29   77178  74752510   QCOM  024800 2000-03-31
# 3        1999-07-22 2023-12-29   77178  74752510   QCOM  024800 2000-06-30
# 4        1999-07-22 2023-12-29   77178  74752510   QCOM  024800 2000-09-30
# ...             ...        ...     ...       ...    ...     ...        ...
# 16683673 1999-10-13 2023-12-29   10138  74144T10   TROW  012138 2022-09-30
# 16683674 1999-10-13 2023-12-29   10138  74144T10   TROW  012138 2022-12-31
# 16683675 1999-10-13 2023-12-29   10138  74144T10   TROW  012138 2023-03-31
# 16683676 1999-10-13 2023-12-29   10138  74144T10   TROW  012138 2023-06-30
# 16683677 1999-10-13 2023-12-29   10138  74144T10   TROW  012138 2023-09-30
#
# [16683678 rows x 7 columns]

# %%
# Create a new DataFrame with selected columns
sp500_link_table = sp500_dates_q[['quarters', 'permno', 'ncusip', 'ticker', 'gvkey']].copy()

# Optional: Reset index if you want a clean index for the new table
sp500_link_table.reset_index(drop=True, inplace=True)

# Display the new table
print(sp500_link_table)
# Out:
#            quarters  permno    ncusip ticker   gvkey
# 0        1999-09-30   77178  74752510   QCOM  024800
# 1        1999-12-31   77178  74752510   QCOM  024800
# 2        2000-03-31   77178  74752510   QCOM  024800
# 3        2000-06-30   77178  74752510   QCOM  024800
# 4        2000-09-30   77178  74752510   QCOM  024800
# ...             ...     ...       ...    ...     ...
# 16683673 2022-09-30   10138  74144T10   TROW  012138
# 16683674 2022-12-31   10138  74144T10   TROW  012138
# 16683675 2023-03-31   10138  74144T10   TROW  012138
# 16683676 2023-06-30   10138  74144T10   TROW  012138
# 16683677 2023-09-30   10138  74144T10   TROW  012138
#
# [16683678 rows x 5 columns]

# %%
print(sp500_link_table.loc[sp500_link_table['permno'] == 77178])
# Out:
#            quarters  permno    ncusip ticker   gvkey
# 0        1999-09-30   77178  74752510   QCOM  024800
# 1        1999-12-31   77178  74752510   QCOM  024800
# 2        2000-03-31   77178  74752510   QCOM  024800
# 3        2000-06-30   77178  74752510   QCOM  024800
# 4        2000-09-30   77178  74752510   QCOM  024800
# ...             ...     ...       ...    ...     ...
# 16676165 2022-09-30   77178  74752510   QCOM  024800
# 16676166 2022-12-31   77178  74752510   QCOM  024800
# 16676167 2023-03-31   77178  74752510   QCOM  024800
# 16676168 2023-06-30   77178  74752510   QCOM  024800
# 16676169 2023-09-30   77178  74752510   QCOM  024800
#
# [27936 rows x 5 columns]

# %%
file_path_1 = 'DS_data/sp500_link_table.csv' 
sp500_link_table.to_csv(file_path_1, index=False)

# %%
# Out:
# ['acti', 'asia', 'asib', 'asic', 'asio', 'asix', 'bmdebt', 'bmheader', 'bmpaymts', 'bmquotes', 'bmyield', 'bndprt06', 'bndprt12', 'bxcalind', 'bxdlyind', 'bxmthind', 'bxquotes', 'bxyield', 'cap', 'ccm_lookup', 'ccm_qvards', 'ccmxpf_linktable', 'ccmxpf_lnkhist', 'ccmxpf_lnkrng', 'ccmxpf_lnkused', 'comphead', 'comphist', 'compmaster', 'contact_info', 'core', 'crsp_cik_map', 'crsp_daily_data', 'crsp_header', 'crsp_monthly_data', 'crsp_names', 'crsp_portno_map', 'crsp_ziman_daily_index', 'crsp_ziman_monthly_index', 'cs20yr', 'cs5yr', 'cs90d', 'cst_hist', 'daily_nav', 'daily_nav_ret', 'daily_returns', 'dividends', 'dport1', 'dport2', 'dport3', 'dport4', 'dport5', 'dport6', 'dport7', 'dport8', 'dport9', 'dsbc', 'dsbo', 'dse', 'dse62', 'dse62delist', 'dse62dist', 'dse62exchdates', 'dse62names', 'dse62nasdin', 'dse62shares', 'dseall', 'dseall62', 'dsedelist', 'dsedist', 'dseexchdates', 'dsenames', 'dsenasdin', 'dseshares', 'dsf', 'dsf62', 'dsf62_v2', 'dsf_v2', 'dsfhdr', 'dsfhdr62', 'dsi', 'dsi62', 'dsia', 'dsib', 'dsic', 'dsio', 'dsir', 'dsix', 'dsiy', 'dsp500', 'dsp500_v2', 'dsp500list', 'dsp500list_v2', 'dsp500p', 'dssc', 'dsso', 'eod_cap', 'eod_core', 'eod_esg', 'eod_sector', 'eod_vg', 'erdport1', 'erdport2', 'erdport3', 'erdport4', 'erdport5', 'erdport6', 'erdport7', 'erdport8', 'erdport9', 'ermport1', 'ermport2', 'ermport3', 'ermport4', 'ermport5', 'esg', 'fbpri', 'fbyld', 'front_load', 'front_load_det', 'front_load_grp', 'fund_fees', 'fund_flows', 'fund_hdr', 'fund_hdr_hist', 'fund_names', 'fund_style', 'fund_summary', 'fund_summary2', 'fwdask06', 'fwdask12', 'fwdave06', 'fwdave12', 'fwdbid06', 'fwdbid12', 'hldask06', 'hldask12', 'hldave06', 'hldave12', 'hldbid06', 'hldbid12', 'holdings', 'holdings_co_info', 'idx_const_close_pf_v2', 'idx_const_close_v2', 'idx_const_open_pf_v2', 'idx_const_open_proj_v2', 'idx_const_open_v2', 'idx_levels', 'inddlyseriesdata', 'inddlyseriesdata62', 'inddlyseriesdata_ind', 'index_descriptions', 'index_type_map', 'indfamilyinfohdr', 'indfamilyinfohdr62', 'indfamilyinfohdr_ind', 'indissrebalancesummary_ind', 'indmthseriesdata', 'indmthseriesdata62', 'indmthseriesdata_ind', 'indsecrebalancesummary_ind', 'indseriesinfohdr', 'indseriesinfohdr62', 'indseriesinfohdr_ind', 'mbi', 'mbmdat', 'mbmhdr', 'mbx', 'mbxid', 'mcti', 'metacalendarperiod', 'metacalendarperiod62', 'metacalendarperiod_ind', 'metacolumncoverage', 'metacolumncoverage62', 'metacolumncoverage_ind', 'metacolumninfo', 'metacolumninfo62', 'metacolumninfo_ind', 'metaexchangecalendar', 'metaexchangecalendar62', 'metaexchangecalendar_ind', 'metafileinfo', 'metafileinfo62', 'metafileinfo_ind', 'metaflagcoverage', 'metaflagcoverage62', 'metaflagcoverage_ind', 'metaflaginfo', 'metaflaginfo62', 'metaflaginfo_ind', 'metaflagtype', 'metaflagtype62', 'metaflagtype_ind', 'metaiteminfo', 'metaiteminfo62', 'metaiteminfo_ind', 'metasiztociz', 'metasiztociz62', 'metasiztociz_ind', 'mfdbname', 'mhista', 'mhistn', 'mhistq', 'monthly_nav', 'monthly_returns', 'monthly_tna', 'monthly_tna_ret_nav', 'mport1', 'mport2', 'mport3', 'mport4', 'mport5', 'mse', 'mse62', 'mse62delist', 'mse62dist', 'mse62exchdates', 'mse62names', 'mse62nasdin', 'mse62shares', 'mseall', 'mseall62', 'msedelist', 'msedist', 'mseexchdates', 'msenames', 'msenasdin', 'mseshares', 'msf', 'msf62', 'msf62_v2', 'msf_v2', 'msfhdr', 'msfhdr62', 'msi', 'msi62', 'msia', 'msib', 'msic', 'msio', 'msir', 'msix', 'msiy', 'msp500', 'msp500_v2', 'msp500list', 'msp500list_v2', 'msp500p', 'portnomap', 'priask06', 'priask12', 'priave06', 'priave12', 'pribid06', 'pribid12', 'price_type', 'property_type', 'qcti', 'qsia', 'qsib', 'qsic', 'qsio', 'qsix', 'rear_load', 'rear_load_det', 'rear_load_grp', 'rebala', 'rebaln', 'rebalq', 'reit_type', 'riskfree', 's6z_agg_ann', 's6z_agg_ann_legacy', 's6z_agg_mth', 's6z_agg_mth_legacy', 's6z_agg_qtr', 's6z_agg_qtr_legacy', 's6z_del', 's6z_del_legacy', 's6z_dind', 's6z_dind_legacy', 's6z_dis', 's6z_dis_legacy', 's6z_dp_dly', 's6z_dp_dly_legacy', 's6z_ds_dly', 's6z_ds_dly_legac ...

# %%
df_1 = pd.read_csv('tnf_us_22q1.csv')
# Out:
# /tmp/ipykernel_4026/2261317062.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv('tnf_us_22q1.csv')

# %%
df_1
# Out:
#          fundno                  fundname mgrcoab        country    shares  \
# 0            73  BMO NORTH AMERICAN DIV F  _EJYTQ  UNITED STATES   31324.0
# 1            73  BMO NORTH AMERICAN DIV F  _EJYTQ  UNITED STATES  157048.0
# 2            73  BMO NORTH AMERICAN DIV F  _EJYTQ  UNITED STATES   11500.0
# 3            73  BMO NORTH AMERICAN DIV F  _EJYTQ  UNITED STATES    7162.0
# 4            73  BMO NORTH AMERICAN DIV F  _EJYTQ  UNITED STATES    3900.0
# ...         ...                       ...     ...            ...       ...
# 2071576  191191   PROSHARES METAVERSE ETF     NaN  UNITED STATES     202.0
# 2071577  191191   PROSHARES METAVERSE ETF     NaN  UNITED STATES   89768.0
# 2071578  191191   PROSHARES METAVERSE ETF     NaN  UNITED STATES   10061.0
# 2071579  191191   PROSHARES METAVERSE ETF     NaN  UNITED STATES     911.0
# 2071580  191191   PROSHARES METAVERSE ETF     NaN  UNITED STATES     533.0
#
#                               stkname ticker     prc  shrout1
# 0                           AGCO CORP   AGCO  146.03     75.0
# 1                            AES CORP    AES   25.73    667.0
# 2                 ABBOTT LABORATORIES    ABT  118.36   1751.0
# 3                   ACUITY BRANDS INC    AYI  189.30     35.0
# 4        AIR PRODUCTS AND CHEMICALS I    APD  249.91    222.0
# ...                               ...    ...     ...      ...
# 2071576           WILLIAMS-SONOMA INC    WSM  145.00     69.0
# 2071577       WIMI HOLOGRAM CLOUD INC   WIMI    2.67     77.0
# 2071578                     ZYNGA INC   ZNGA    9.24   1137.0
# 2071579                 AMBARELLA INC    NaN  104.92     38.0
# 2071580                    GLOBANT SA   GLOB  262.07     42.0
#
# [2071581 rows x 9 columns]

# %%
Russell_1000 = df_1[df_1['fundname'].str.contains('1000', case=False, na=False)].drop_duplicates(subset='fundname')

# %%
Russell_1000
# Out:
#          fundno                  fundname mgrcoab        country     shares  \
# 589714    52100  SCHWAB 1000 INDEX (R) FU  SCHWAB  UNITED STATES    48281.0
# 630301    56763  ISHARES RUSSELL1000VAL I  _EJZOE  UNITED STATES   439417.0
# 637524    56804  ISHARES RUSSELL 1000 IND  _EJZOE  UNITED STATES   102181.0
# 638547    56805  ISHARES RUSSELL1000 GR I  _EJZOE  UNITED STATES    20034.0
# 1089658   95587  SPDR RUSSELL1000 YLD FOC     NaN  UNITED STATES    18438.0
# 1224334  106050  POWERSHARES RUSSELL1000L     NaN  UNITED STATES     1172.0
# 1267019  112988  SPDR RUSSELL1000MOMENTUM     NaN  UNITED STATES     3207.0
# 1321790  117073  VANGUARD RUSSELL1000GR I     NaN  UNITED STATES     2929.0
# 1428279  128232  POWERSHARES RUSSELL1000E     NaN  UNITED STATES    49942.0
# 1456177  132142  SPDR RUSSELL1000LOW VOLA     NaN  UNITED STATES    27824.0
# 1502280  138236   VANGUARD RUSSELL1000VAL     NaN  UNITED STATES    70453.0
# 1540991  143501     SCHWAB 1000 INDEX ETF     NaN  UNITED STATES     8069.0
# 1562166  145188  DIREXION RUSSELL 1000 VA     NaN  UNITED STATES  1846099.0
# 1584982  147144  INVESCO RUSSELL 1000 DYN     NaN  UNITED STATES   202388.0
# 1654756  152756  DIREXION RUSSELL 1000 GR     NaN  UNITED STATES   772245.0
# 1887223  170214  INVESCO RUSSELL 1000 ENH     NaN  UNITED STATES      100.0
# 1888182  170333  VANGUARD RUSSELL 1000 IN     NaN  UNITED STATES    21250.0
# 1973272  177744  XTRACKERS RUSSELL 1000 U     NaN  UNITED STATES      210.0
#
#                               stkname ticker     prc  shrout1
# 589714                        ADT INC    ADT    7.59    851.0
# 630301                        ADT INC    ADT    7.59    851.0
# 637524                        ADT INC    ADT    7.59    851.0
# 638547                      AGCO CORP   AGCO  146.03     75.0
# 1089658                       ADT INC    ADT    7.59    851.0
# 1224334          AGNC INVESTMENT CORP   AGNC   13.10    523.0
# 1267019                       ADT INC    ADT    7.59    851.0
# 1321790                     AGCO CORP   AGCO  146.03     75.0
# 1428279                       ADT INC    ADT    7.59    851.0
# 1456177                     AFLAC INC    AFL   64.39    649.0
# 1502280                       ADT INC    ADT    7.59    851.0
# 1540991                       ADT INC    ADT    7.59    851.0
# 1562166  DREYFUS GOVERNMENT CASH MANA   DGCX    1.00      NaN
# 1584982           ABBOTT LABORATORIES    ABT  118.36   1751.0
# 1654756  DREYFUS GOVERNMENT CASH MANA   DGCX    1.00      NaN
# 1887223                     AFLAC INC    AFL   64.39    649.0
# 1888182                       ADT INC    ADT    7.59    851.0
# 1973272                     AFLAC INC    AFL   64.39    649.0

# %%
Russell_3000 = df_1[df_1['fundname'].str.contains('3000', case=False, na=False)].drop_duplicates(subset='fundname')
Russell_3000
# Out:
#          fundno                  fundname mgrcoab        country    shares  \
# 631152    56769  ISHARES RUSSELL 3000 IND  _EJZOE  UNITED STATES   10642.0
# 640859    56871  ISHARES RUSSELL3000 GR I  _EJZOE  UNITED STATES   32588.0
# 641330    56883  ISHARES RUSSELL3000VAL I  _EJZOE  UNITED STATES  360472.0
# 1843519  167165  VANGUARD RUSSELL 3000 IN     NaN  UNITED STATES    2128.0
#
#            stkname ticker     prc  shrout1
# 631152    AAON INC   AAON   55.73     53.0
# 640859    ASGN INC   ASGN  116.71     51.0
# 641330   AFLAC INC    AFL   64.39    649.0
# 1843519   AAON INC   AAON   55.73     53.0

# %%
sp_500 = df_1[df_1['fundname'].str.contains('500', case=False, na=False)].drop_duplicates(subset='fundname')
sp_500
# Out:
#          fundno                  fundname mgrcoab        country      shares  \
# 150940   177427  CBOE VEST SP 500 DIV ARS     NaN  UNITED STATES     20320.0
# 164421     7995  DWS EQUITY 500 INDEX POR  _FRFSP  UNITED STATES     29442.0
# 179491    81045  DIREXION MTHLY S&P500BEA  _EKGDK  UNITED STATES   2392275.0
# 179492    81046  DIREXION MTHLY S&P500BUL  _EKGDK  UNITED STATES  11780000.0
# 209564   177426  STATE STREET SP 500 INDE     NaN  UNITED STATES     25474.0
# ...         ...                       ...     ...            ...         ...
# 2062299  190540  DIREXION DAILY SP 500 EQ     NaN  UNITED STATES   1268157.0
# 2062702  190562   MLLMN 6MO BFFRD SP500 W     NaN  UNITED STATES      1049.0
# 2062752  190574  MLLMN 1YR BFRD SP500 NAS     NaN  UNITED STATES      1000.0
# 2064662  190721  MLLMN 6YR PRDOWN SP500 W     NaN  UNITED STATES     11570.0
# 2066272  190996  MLLMN 6YR BFRD SP500 W P     NaN  UNITED STATES     11570.0
#
#                               stkname ticker     prc  shrout1
# 150940                      AFLAC INC    AFL   64.39    649.0
# 164421                      AFLAC INC    AFL   64.39    649.0
# 179491   GOLDMAN SACHS FOCUSED INTERN   FTIX    1.00      NaN
# 179492   FIDELITY COLCHESTER STREET T   FRGX    1.00      NaN
# 209564                      AFLAC INC    AFL   64.39    649.0
# ...                               ...    ...     ...      ...
# 2062299  DREYFUS GOVERNMENT CASH MANA   DGCX    1.00      NaN
# 2062702  ISHARES 03 MONTH TREASURY BO   SGOV  100.05     20.0
# 2062752  ISHARES 03 MONTH TREASURY BO   SGOV  100.05     20.0
# 2064662  INVESCO BULLETSHARES 2029 CO   BSCT   19.45      7.0
# 2066272  INVESCO BULLETSHARES 2029 CO   BSCT   19.45      7.0
#
# [138 rows x 9 columns]

# %%
# str.contains('index', case=False, na=False) 
# when no (case=False), the letter case is sensitive
IND = df_1[df_1['fundname'].str.endswith(' IND')].drop_duplicates(subset='fundname')
IND
# Out:
#          fundno                  fundname mgrcoab        country       shares  \
# 204844   164735  PRAXIS INTERNATIONAL IND     NaN  UNITED STATES      33452.0
# 328258     5677  ISHARES RUSSELL 2000 IND  _EJZOE  UNITED STATES     944645.0
# 330270     5705  ISHARES DOW JONES US IND  _EJZOE  UNITED STATES      40560.0
# 360270     9753  FIDELITY GBL EX U.S. IND  _FTNOW  UNITED STATES     560908.0
# 363339     9821  VANGUARD GBL SML-CAP IND  VGUARD  UNITED STATES      18975.0
# 373139    12485  ISHARES MSCI AUSTRLA IND  _EJZOE  UNITED STATES     880000.0
# 373201    12490  VANGUARD PACIFIC STK IND  VGUARD  UNITED STATES      17210.0
# 377178    12495  ISHARES MSCI GERMANY IND  _EJZOE  UNITED STATES     890000.0
# 388447    15469  FIDELITY MSCI ENERGY IND     NaN  UNITED STATES      72133.0
# 429167    28948  METLIFE RUSSELL 2000 IND     NaN  UNITED STATES      14309.0
# 436727    30539  VANGUARD REAL ESTATE IND     NaN  UNITED STATES      78193.0
# 492745    42819  VANGUARD HEALTH CARE IND  VGUARD  UNITED STATES      26701.0
# 531860    45669  VANGUARD INDUSTRIALS IND  VGUARD  UNITED STATES      51906.0
# 590705    52150  SCHWAB SMALL CAPITAL IND  SCHWAB  UNITED STATES      93925.0
# 628706    56590  OHIO NATL NASDAQ 100 IND  ONINVT  UNITED STATES      17819.0
# 631152    56769  ISHARES RUSSELL 3000 IND  _EJZOE  UNITED STATES      10642.0
# 637524    56804  ISHARES RUSSELL 1000 IND  _EJZOE  UNITED STATES     102181.0
# 640154    56811  ISHARES S&P EURO 350 IND  _EJZOE  UNITED STATES    2640000.0
# 640517    56813  ISHARES S&P 500 GWTH IND  _EJZOE  UNITED STATES    1775021.0
# 651567    57776  T ROWE PRICE INTL EQ IND   PRICE  UNITED STATES       9800.0
# 657956    58892  VALIC I NASDAQ   100 IND   SUNAM  UNITED STATES      47416.0
# 663231    59844  VANGUARD FTSE SOCIAL IND  VGUARD  UNITED STATES     307456.0
# 690859    62242  VANGUARD TOT STK MKT IND  VGUARD  UNITED STATES     445926.0
# 718461    64725  NATIONWIDE SMALL CAP IND  _EJZOE  UNITED STATES       3974.0
# 745691    67999  INVESCO V.I. S&P 500 IND  CHANCP  UNITED STATES       1445.0
# 820623    69980  NORTH AMER AG MIDCAP IND  _EJYHR  UNITED STATES      92007.0
# 829077    73270  JNL SER TR MELLON BD IND  _EJXMZ  UNITED STATES  126191582.0
# 856373    79070  ISHARES MSCI EAFE GR IND  _EJZOE  UNITED STATES    2670000.0
# 865063    79928  NATIONWIDE NVIT INTL IND  _EJZOE  UNITED STATES      27200.0
# 869312    80073  VANGUARD JAPAN STOCK IND  VGUARD  UNITED STATES     281277.0
# 889812    80494  FIDELITY FOUR-IN-ONE IND   FIDEL  UNITED STATES   43171650.0
# 898865    80811  FIRST TR DJ INTERNET IND  _EZSDG  UNITED STATES    1234099.0
# 912043    81082  CLAYMORE MULTI ASSET IND  _EKDKM  UNITED STATES      19303.0
# 941592    82571  FIRST TRUST S&P REIT IND  _EZSDG  UNITED STATES      16369.0
# 978064    82887  ISHARES MSCI KOKUSAI IND  _EJZOE  UNITED STATES       2191.0
# 1089631   95480  GUGGENHEIM DOW JONES IND     NaN  UNITED STATES      14283.0
# 1143486   99639  ISHARES ESG MSCI USA IND     NaN  UNITED STATES      10738.0
# 1237126  108723  NORTHERN INTL EQUITY IND  _FRFSP  UNITED STATES      69500.0
# 1253169  110543  VANGUARD FTSE CANADA IND     NaN  UNITED STATES     252521.0
# 1265822  112773   GOLDMAN SACHS HEDGE IND     NaN  UNITED STATES      32149.0
# 1291306  115540  VANGUARD TOT WLD STK IND  VGUARD  UNITED STATES      19811.0
# 1340708  117377  POWERSHARES CNDN DIV IND     NaN  UNITED STATES     706808.0
# 1359763  120052  UNITED STATES COPPER IND     NaN  UNITED STATES   60250000.0
# 1469178  133488  SEI INST INV S&P 500 IND     NaN  UNITED STATES      90182.0
# 1487226  136899  VANGUARD GLOBAL BOND IND     NaN  UNITED STATES     150000.0
# 1503770  138387  LINCOLN SSGA MID-CAP IND     NaN  UNITED STATES      26830.0
# 1698074  157703  FIDELITY MSCI EUROPE IND     NaN  UNITED STATES      16574.0
# 1737433  160233  ISHARES US SMALL CAP IND     NaN  UNITED STATES    2129470.0
# 1750223  161169  FIDELITY REAL ESTATE IND     NaN  UNITED STATES     165539.0
# 1884527  170139  INVESCO DB COMMODITY IND     NaN  UNITED STATES    1825900.0
# 1940181  174294  FIDELITY US MOMENTUM IND     NaN  UNITED STATES        936.0
# 2018683  183611  JNL EMERGING MARKETS IND     NaN  UNITED STATES      18700.0
#
#                               stkname ticker     prc  shrout1
# 204844                        ABB LTD    ABB   32.34   1929.0
# 328258                       AAON INC   AAON   55.73     53.0
# 330270                        ADT INC    ADT    7.59    851.0
# 360270         AGNICO EAGLE MINES LTD   AEM/   61.20    456.0
# 363339                       AAON INC   AAON   55.73     53.0
# 373139   BLACKROCK CASH FUNDS TREASUR    NaN    1.00      NaN
# 373201           PROCREA HOLDINGS INC   7384     NaN     29.0
# 377178   BLACKROCK CASH FUNDS TREASUR    NaN    1.00      NaN
# 388447           ALTO INGREDIENTS INC   ALTO    6.82     74.0
# 429167                       AAON INC   AAON   55.73     53.0
# 436727            ACADIA REALTY TRUST    AKR   21.67     94.0
# 492745      ALX ONCOLOGY HOLDINGS INC   ALXO   16.90     41.0
# 531860                       AAON INC   AAON   55.73     53.0
# 590705                       AAON INC   AAON   55.73     53.0
# 628706        ACTIVISION BLIZZARD INC   ATVI   80.11    781.0
# 631152                       AAON INC   AAON   55.73     53.0
# 637524                        ADT INC    ADT    7.59    851.0
# 640154   BLACKROCK CASH FUNDS TREASUR    NaN    1.00      NaN
# 640517            ABBOTT LABORATORIES    ABT  118.36   1751.0
# 651567               BROTHER INDS LTD   BRTH   18.39    262.0
# 657956        ACTIVISION BLIZZARD INC   ATVI   80.11    781.0
# 663231                      AFLAC INC    AFL   64.39    649.0
# 690859            AADI BIOSCIENCE INC   AADI   16.97     21.0
# 718461                       AAON INC   AAON   55.73     53.0
# 745691                      AFLAC INC    AFL   64.39    649.0
# 820623                      AGCO CORP   AGCO  146.03     75.0
# 829077            JNL BOND INDEX FUND    NaN    9.48      NaN
# 856373   BLACKROCK CASH FUNDS TREASUR    NaN    1.00      NaN
# 865063               BROTHER INDS LTD   BRTH   18.39    262.0
# 869312               BROTHER INDS LTD   BRTH   18.39    262.0
# 889812   FIDELITY SPARTAN US BOND IND   FSPS   45.99      NaN
# 898865                     AIRBNB INC   ABNB  171.76    371.0
# 912043                      AFLAC INC    AFL   64.39    649.0
# 941592            ACADIA REALTY TRUST    AKR   21.67     94.0
# 978064                      AFLAC INC    AFL   64.39    649.0
# 1089631           AMERICAN EXPRESS CO    AXP  187.00    757.0
# 1143486                      AT&T INC      T   23.63   7143.0
# 1237126              BROTHER INDS LTD   BRTH   18.39    262.0
# 1253169        AGNICO EAGLE MINES LTD   AEM/   61.20    456.0
# 1265822     ALIBABA GROUP HOLDING LTD   BABA  108.80   2700.0
# 1291306                      AAON INC   AAON   55.73     53.0
# 1340708   ALGONQUIN POWER & UTILITIES   AQN/   15.51    674.0
# 1359763  FINANCIAL SQUARE PRIME OBLIG   FGTX    1.00      NaN
# 1469178                     AFLAC INC    AFL   64.39    649.0
# 1487226  THAMES WATER UTILITIES FINAN   94NA  162.52      NaN
# 1503770                     AGCO CORP   AGCO  146.03     75.0
# 1698074                 TELEFONICA SA    TEF    4.86   5779.0
# 1737433  ISHARES CORE S&P SMALL-CAP E    IWM  205.27    303.0
# 1750223           ACADIA REALTY TRUST    AKR   21.67     94.0
# 1884527   INVESCO TREASURY COLLATERAL   CLTL  105.55      6.0
# 1940181  AMC ENTERTAINMENT HOLDINGS I    AMC   24.64    517.0
# 2018683          HUAXIN CEMENT CO LTD   6655    1.73    735.0

# %%
ind_pattern = 'INDEX|1000|2000|3000|500' 
IND = df_1[
    df_1['fundname'].str.endswith('IND') | 
    df_1['fundname'].str.contains(ind_pattern)
].drop_duplicates(subset='fundname')

print(IND)
# Out:
#          fundno                  fundname mgrcoab        country      shares  \
# 150940   177427  CBOE VEST SP 500 DIV ARS     NaN  UNITED STATES     20320.0
# 164421     7995  DWS EQUITY 500 INDEX POR  _FRFSP  UNITED STATES     29442.0
# 174129    62943  MMA PRAXIS VALUE INDEX F  MMACAP  UNITED STATES     38140.0
# 179491    81045  DIREXION MTHLY S&P500BEA  _EKGDK  UNITED STATES   2392275.0
# 179492    81046  DIREXION MTHLY S&P500BUL  _EKGDK  UNITED STATES  11780000.0
# ...         ...                       ...     ...            ...         ...
# 2062299  190540  DIREXION DAILY SP 500 EQ     NaN  UNITED STATES   1268157.0
# 2062702  190562   MLLMN 6MO BFFRD SP500 W     NaN  UNITED STATES      1049.0
# 2062752  190574  MLLMN 1YR BFRD SP500 NAS     NaN  UNITED STATES      1000.0
# 2064662  190721  MLLMN 6YR PRDOWN SP500 W     NaN  UNITED STATES     11570.0
# 2066272  190996  MLLMN 6YR BFRD SP500 W P     NaN  UNITED STATES     11570.0
#
#                               stkname ticker     prc  shrout1
# 150940                      AFLAC INC    AFL   64.39    649.0
# 164421                      AFLAC INC    AFL   64.39    649.0
# 174129                      AFLAC INC    AFL   64.39    649.0
# 179491   GOLDMAN SACHS FOCUSED INTERN   FTIX    1.00      NaN
# 179492   FIDELITY COLCHESTER STREET T   FRGX    1.00      NaN
# ...                               ...    ...     ...      ...
# 2062299  DREYFUS GOVERNMENT CASH MANA   DGCX    1.00      NaN
# 2062702  ISHARES 03 MONTH TREASURY BO   SGOV  100.05     20.0
# 2062752  ISHARES 03 MONTH TREASURY BO   SGOV  100.05     20.0
# 2064662  INVESCO BULLETSHARES 2029 CO   BSCT   19.45      7.0
# 2066272  INVESCO BULLETSHARES 2029 CO   BSCT   19.45      7.0
#
# [395 rows x 9 columns]
